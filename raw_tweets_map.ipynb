# %%
import plotly.plotly as py
import pandas as pd
import seaborn as sns

# %%
import plotly 
plotly.tools.set_credentials_file(username='racquesta', api_key='mEcy6kAYKdM15kgu2r7Y')

# %%
state_count = pd.read_csv('normalized_counts.csv')

# %%
state_count.head()
# Out:
#    Unnamed: 0       State  Total Population State Abbr  black  jews  muslim  \
# 0           0     Alabama           4863300         AL    1.0   1.0     4.0
# 1           1      Alaska            741894         AK    1.0   0.0     1.0
# 2           2     Arizona           6931071         AZ    1.0   0.0     4.0
# 3           3    Arkansas           2988248         AR    3.0   1.0     3.0
# 4           4  California          39250017         CA   30.0  31.0    17.0
#
#    norm_black  norm_jewish  norm_muslim  total_count  total_norm
# 0    0.000021     0.000021     0.000082          6.0    0.000123
# 1    0.000135     0.000000     0.000135          2.0    0.000270
# 2    0.000014     0.000000     0.000058          5.0    0.000072
# 3    0.000100     0.000033     0.000100          7.0    0.000234
# 4    0.000076     0.000079     0.000043         78.0    0.000199

# %%
state_count = state_count.drop([8])

# %%
state_count.sort_values('total_norm', ascending = False)
# Out:
#     Unnamed: 0           State  Total Population State Abbr  black  jews  \
# 40          45         Vermont            624594         VT    2.0   1.0
# 22          24     Mississippi           2988726         MS    5.0   1.0
# 7            7        Delaware            952065         DE    3.0   1.0
# 20          22        Michigan           9928300         MI   16.0   9.0
# 35          39    Rhode Island           1056426         RI    1.0   1.0
# 28          32        New York          19745289         NY   20.0  22.0
# 16          18       Louisiana           4681666         LA    8.0   2.0
# 1            1          Alaska            741894         AK    1.0   0.0
# 36          40  South Carolina           4961119         SC    4.0   5.0
# 25          28          Nevada           2940058         NV    4.0   1.0
# 38          43           Texas          27862596         TX   21.0  27.0
# 3            3        Arkansas           2988248         AR    3.0   1.0
# ...

# %%
state_count['total_norm1'] = state_count['total_norm']/state_count['total_norm'].max()
state_count['black_norm1'] = state_count['norm_black']/state_count['norm_black'].max()
state_count['jewish_norm1'] = state_count['norm_jewish']/state_count['norm_jewish'].max()
state_count['muslim_norm1'] = state_count['norm_muslim']/state_count['norm_muslim'].max()

# %%
state_count
# Out:
#     Unnamed: 0           State  Total Population State Abbr  black  jews  \
# 0            0         Alabama           4863300         AL    1.0   1.0
# 1            1          Alaska            741894         AK    1.0   0.0
# 2            2         Arizona           6931071         AZ    1.0   0.0
# 3            3        Arkansas           2988248         AR    3.0   1.0
# 4            4      California          39250017         CA   30.0  31.0
# 5            5        Colorado           5540545         CO    4.0   0.0
# 6            6     Connecticut           3576452         CT    2.0   2.0
# 7            7        Delaware            952065         DE    3.0   1.0
# 9            9         Florida          20612439         FL   19.0  13.0
# 10          10         Georgia          10310371         GA   10.0   5.0
# 11          12           Idaho           1683140         ID    0.0   1.0
# 12          13        Illinois          12801539         IL   11.0   2.0
# ...

# %%
state_count.to_csv('norm_totals_by_race.csv', index = False)

# %%
import colorlover as cl
from IPython.display import HTML
import plotly.graph_objs as go

# %%
scl = cl.scales['9']['seq']['Reds']
scl = ['rgb(255,245,240)',
 'rgb(254,224,210)',
 'rgb(252,187,161)',
 'rgb(252,146,114)',
 'rgb(251,106,74)',
 'rgb(239,59,44)',
 'rgb(203,24,29)',
 'rgb(165,15,21)',
 'rgb(103,0,13)']
HTML( cl.to_html(scl) )
scl
# Out:
# ['rgb(255,245,240)',
#  'rgb(254,224,210)',
#  'rgb(252,187,161)',
#  'rgb(252,146,114)',
#  'rgb(251,106,74)',
#  'rgb(239,59,44)',
#  'rgb(203,24,29)',
#  'rgb(165,15,21)',
#  'rgb(103,0,13)']

# %%
new_scl = []
num = 0.0
for color in scl:
    new_scl.append([num, color])
    num += 1/8
new_scl
# Out:
# [[0.0, 'rgb(255,245,240)'],
#  [0.125, 'rgb(254,224,210)'],
#  [0.25, 'rgb(252,187,161)'],
#  [0.375, 'rgb(252,146,114)'],
#  [0.5, 'rgb(251,106,74)'],
#  [0.625, 'rgb(239,59,44)'],
#  [0.75, 'rgb(203,24,29)'],
#  [0.875, 'rgb(165,15,21)'],
#  [1.0, 'rgb(103,0,13)']]

# %%
data = [ dict(
        type='choropleth',
        colorscale = new_scl,
        autocolorscale = False,
        locations = state_count['State Abbr'],
        z = state_count['jewish_norm1'],
        locationmode = 'USA-states',
        #text = df['text'],
        marker = dict(
            line = dict (
                color = 'white',
                width = 2
            ) ),
        colorbar = dict(
            title = "% of population")
        ) ]

# %%
layout = dict(
        title = '2011 US Agriculture Exports by State<br>(Hover for breakdown)',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = False,
            lakecolor = None),
             )

# %%
from plotly.graph_objs import *

# %%
fig = dict( data=data, layout=layout )
#url = py.offline.iplot(fig, filename='d3-cloropleth-map')
#print(url)
py.image.save_as(fig, filename='a-simple-plot.png')
py.iplot( fig, filename='d3-cloropleth-map' )
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~racquesta/0 or inside your plot.ly account where it is named 'd3-cloropleth-map'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~racquesta/0.embed" height="525px" width="100%"></iframe>

# %%
mus
