# %%
import pandas as pd

# %%
# frames = [df1, df2, df3]

# In [5]: result = pd.concat(frames)

# %%
racist1 = pd.read_csv('ronessa.csv', encoding = 'utf-8')
racist2 = pd.read_csv('sharanya.csv', encoding = 'utf-8')
racist3 = pd.read_csv('mariah.csv', encoding = 'utf-8')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens (pandas/_libs/parsers.c:14858)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype (pandas/_libs/parsers.c:17119)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert (pandas/_libs/parsers.c:17347)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8 (pandas/_libs/parsers.c:23041)()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe3 in position 19: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-6-6756b882061f> in <module>()
# ----> 1 racist1 = pd.read_csv('ronessa.csv', encoding = 'utf-8')
# ...

# %%
frames = [racist1, racist2, racist3]

# %%
everything = pd.concat(frames)

# %%
len(everything)
# Out:
# 10258

# %%
# clean up
everything = everything.drop_duplicates()

# %%
len(everything)
# Out:
# 10258

# %%
no_dup_tweet = everything.drop_duplicates(subset = ['tweet'])

# %%
len(no_dup_tweet)
# Out:
# 9509

# %%
no_dup_tweet.to_csv('joined_results.csv')

# %%
result = pd.read_csv('class_output2.csv', header = None)

# %%
len(result)
# Out:
# 9509

# %%
result.head()
# Out:
#              0
# 0  Hate speech
# 1      Neither
# 2  Hate speech
# 3      Neither
# 4  Hate speech

# %%
no_dup_tweet['classification'] = result[0]
# Out:
# /Users/ronessaacquesta/anaconda/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
no_dup_tweet
# Out:
#       Unnamed: 0  # favorite of tweet  # followers  # following  # of hastags  \
# 0              0                  0.0       1035.0        695.0           0.0
# 1              1                  0.0       3418.0        848.0           0.0
# 2              2                  0.0       2700.0        933.0           0.0
# 3              3                  0.0        458.0        857.0           0.0
# 4              4                  0.0         34.0         80.0           0.0
# 5              5                  0.0        317.0        913.0           0.0
# 6              6                  1.0       3007.0       5000.0           0.0
# 7              7                  0.0        279.0        568.0           0.0
# 8              8                  0.0          0.0         38.0           0.0
# 9              9                  0.0       2090.0        669.0           0.0
# 10            10                  0.0        958.0       2610.0           0.0
# ...

# %%
len(no_dup_tweet)
# Out:
# 9509

# %%
hate_speech = no_dup_tweet[no_dup_tweet['classification'] == 'Hate speech']

# %%
len(hate_speech)
# Out:
# 4228

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
no_dup_tweet['compound score'] = "" 

for index, row in no_dup_tweet.iterrows():
    try:
        text = row['tweet']
        compound = analyzer.polarity_scores(text)['compound']
        no_dup_tweet.set_value(index, 'compound score', compound)
    except:
        print('error at %s, %s' % (index, row['tweet']))
# Out:
# /Users/ronessaacquesta/anaconda/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
no_dup_tweet.head()
# Out:
#    Unnamed: 0  # favorite of tweet  # followers  # following  # of hastags  \
# 0           0                  0.0       1035.0        695.0           0.0
# 1           1                  0.0       3418.0        848.0           0.0
# 2           2                  0.0       2700.0        933.0           0.0
# 3           3                  0.0        458.0        857.0           0.0
# 4           4                  0.0         34.0         80.0           0.0
#
#    # of mentions  # retweets of tweet           account creation date  \
# 0            0.0                  1.0  Mon May 10 20:46:10 +0000 2010
# 1            0.0                  0.0  Fri Apr 18 00:04:37 +0000 2014
# 2            2.0                  0.0  Mon Oct 24 06:42:43 +0000 2011
# 3            4.0                  0.0  Fri Mar 04 18:31:03 +0000 2011
# 4            2.0                  0.0  Mon Jun 06 20:29:37 +0000 2016
#
#     in reply to         location                 name  \
# ...

# %%
no_dup_tweet.to_csv('all_together_scores.csv', index = False)
