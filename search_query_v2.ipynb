# %%
import tweepy
import json
import keys
from hate_speech1 import race_dict

# get keys
consumer_key = "dhdP8LaOYfkxmxi9Fwde6XtNs"
consumer_secret = "52yu7buJCQdZ44f9niYauSg6aXHLqHUKjZVXM8HqPxYooKPWVB"
access_token = "1570660926-Ck2MtiaK9ys8AiyDUBsgL3RV3in8GigvkcUPRAp"
access_token_secret = "765YZYKpMvfK8PDXWUxCa2yxZKnf5auAiASwpLNxYCbGO"

#autheticate
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser(), wait_on_rate_limit = True, wait_on_rate_limit_notify = True)

#data lists
race_list = []
phrase = []
time = []
text = []
num_hashtags = []
hashtag_list = []
num_user_mentions = []
user_id = []
name = []
screen_name = []
account_creation_time = []
user_tweet_count = []
location = []
num_followers = []
num_following = []
num_retweets = []
num_favorites = []
in_reply_to = []

phrase_list = []

def search_phrase(race):
    for name in race_dict[race]:
        race = name
        phrase0 = race + ' people are'
        phrase1 = race + ' are'
        phrase2 = 'all ' + race + ' are'
        phrase3 = 'i hate ' + race
        phrase4 = 'i hate all ' + race
        phrase5 = 'down with the ' + race
        phrase_list.append(phrase0)
        phrase_list.append(phrase1)
        phrase_list.append(phrase2)
        phrase_list.append(phrase3)
        phrase_list.append(phrase4)
        phrase_list.append(phrase5)

# def search_phrases(phrase_list):
#         for entry in phrase_list: 
#             print(entry)



def search_request(race_name, search_term):
    page_num = 1
    for x in range(10):
        if x == 0:
            end_id = None
        try: #-filter:retweets   #and (not tweet["retweeted"]) and ("RT" not in tweet["text"]) REMOVE RETWEET DUPLICATES
            response = api.search(search_term, lang = "en", count = 100, max_id = end_id, geocode="39.82,-98.57,1500mi")['statuses']
            for tweet in response:
                tweet_text = tweet['text']
                if (search_term in tweet_text and "RT" not in tweet_text): #
                    race_list.append(race_name)
                    phrase.append(search_term)
                    time.append(tweet['created_at'])
                    text.append(tweet['text'])
                    num_hashtags_tweet = len(tweet['entities']['hashtags'])
                    num_hashtags.append(num_hashtags_tweet)
                    hashtags = []
                    if num_hashtags_tweet > 0:
                        for hastag_text in tweet['entities']['hashtags']:
                            hashtags.append(hastag_text['text'])
                    hashtag_list.append(hashtags)
                    num_user_mentions.append(len(tweet['entities']['user_mentions']))
                    user_id.append(tweet['user']['id'])
                    screen_name.append(tweet['user']['screen_name'])
                    name.append(tweet['user']['name'])
                    account_creation_time.append(tweet['user']['created_at'])
                    user_tweet_count.append(tweet['user']['statuses_count'])
                    location.append(tweet['user']['location']) 
                    num_followers.append(tweet['user']['followers_count'])
                    num_following.append(tweet['user']['friends_count'])
                    num_retweets.append(tweet['retweet_count'])
                    num_favorites.append(tweet["favorite_count"])  
                    in_reply_to.append(tweet["in_reply_to_user_id"]) 
            end_id = response[-1]['id'] - 1
            print("Search Results Found for %s: page # %s" % (search_term, page_num))
        except: 
            print('Error on phrase: %s, page # %s' % (search_term, page_num))
        page_num += 1
        
# for term in black:
#     slur = term.lower()
#     search_request(slur)
#     print("Results for %s: %s" % (term, len(word)))


for key in race_dict.keys():
    search_phrase(key)
    for phrase in phrase_list:
        search_request(key, phrase)

# search_request('trump')
# print(location)
# print(text)


# user_location = []
# profile_location = []
# timezone = []


# def user_location():
#     for name in screen_name:
#         try: #-filter:retweets   #and (not tweet["retweeted"]) and ("RT" not in tweet["text"])
#             response = api.get_user(name)
#             for tweet in response:
#                 user_location.append(response["location"])
#                 profile_location.append(response["profile_location"])
#                 timezone.append(response["time_zone"])
#         except: 
#             print('Error on word: %s' % (name))


# user_location()

# print(user_location)
# print(profile_location)
# print(timezone)
# Out:
# Rate limit reached. Sleeping for: 270
# Error on phrase: black people are, page # 1
# Error on phrase: black people are, page # 2
# Error on phrase: black people are, page # 3
# Error on phrase: black people are, page # 4
# Error on phrase: black people are, page # 5
# Error on phrase: black people are, page # 6
# Error on phrase: black people are, page # 7
# Error on phrase: black people are, page # 8
# Error on phrase: black people are, page # 9
# Error on phrase: black people are, page # 10
# Search Results Found for black are: page # 1
# Search Results Found for black are: page # 2
# Search Results Found for black are: page # 3
# Search Results Found for black are: page # 4
# Error on phrase: black are, page # 5
# Error on phrase: black are, page # 6
# Error on phrase: black are, page # 7
# Error on phrase: black are, page # 8
# Error on phrase: black are, page # 9
# Error on phrase: black are, page # 10
# Search Results Found for all black are: page # 1
# Search Results Found for all black are: page # 2
# Search Results Found for all black are: page # 3
# Search Results Found for all black are: page # 4
# Search Results Found for all black are: page # 5
# Search Results Found for all black are: page # 6
# Search Results Found for all black are: page # 7
# Search Results Found for all black are: page # 8
# Search Results Found for all black are: page # 9
# Search Results Found for all black are: page # 10
# Search Results Found for i hate black: page # 1
# Search Results Found for i hate black: page # 2
# Search Results Found for i hate black: page # 3
# Error on phrase: i hate black, page # 4
# Error on phrase: i hate black, page # 5
# Error on phrase: i hate black, page # 6
# Error on phrase: i hate black, page # 7
# Error on phrase: i hate black, page # 8
# Error on phrase: i hate black, page # 9
# Error on phrase: i hate black, page # 10
# Search Results Found for i hate all black: page # 1
# Error on phrase: i hate all black, page # 2
# Error on phrase: i hate all black, page # 3
# Error on phrase: i hate all black, page # 4
# Error on phrase: i hate all black, page # 5
# Error on phrase: i hate all black, page # 6
# Error on phrase: i hate all black, page # 7
# Error on phrase: i hate all black, page # 8
# Error on phrase: i hate all black, page # 9
# Error on phrase: i hate all black, page # 10
# Search Results Found for down with the black: page # 1
# Error on phrase: down with the black, page # 2
# Error on phrase: down with the black, page # 3
# Error on phrase: down with the black, page # 4
# Error on phrase: down with the black, page # 5
# Error on phrase: down with the black, page # 6
# Error on phrase: down with the black, page # 7
# Error on phrase: down with the black, page # 8
# Error on phrase: down with the black, page # 9
# Error on phrase: down with the black, page # 10
# Search Results Found for nigger people are: page # 1
# Search Results Found for nigger people are: page # 2
# Error on phrase: nigger people are, page # 3
# Error on phrase: nigger people are, page # 4
# Error on phrase: nigger people are, page # 5
# Error on phrase: nigger people are, page # 6
# Error on phrase: nigger people are, page # 7
# Error on phrase: nigger people are, page # 8
# Error on phrase: nigger people are, page # 9
# Error on phrase: nigger people are, page # 10
# Error on phrase: nigger are, page # 1
# Error on phrase: nigger are, page # 2
# Error on phrase: nigger are, page # 3
# Error on phrase: nigger are, page # 4
# Error on phrase: nigger are, page # 5
# Error on phrase: nigger are, page # 6
# Error on phrase: nigger are, page # 7
# Error on phrase: nigger are, page # 8
# Error on phrase: nigger are, page # 9
# Error on phrase: nigger are, page # 10
# Search Results Found for all nigger are: page # 1
# Error on phrase: all nigger are, page # 2
# Error on phrase: all nigger are, page # 3
# Error on phrase: all nigger are, page # 4
# Error on phrase: all nigger are, page # 5
# Error on phrase: all nigger are, page # 6
# Error on phrase: all nigger are, page # 7
# Error on phrase: all nigger are, page # 8
# Error on phrase: all nigger are, page # 9
# Error on phrase: all nigger are, page # 10
# Search Results Found for i hate nigger: page # 1
# Error on phrase: i hate nigger, page # 2
# Error on phrase: i hate nigger, page # 3
# Error on phrase: i hate nigger, page # 4
# Error on phrase: i hate nigger, page # 5
# Error on phrase: i hate nigger, page # 6
# Error on phrase: i hate nigger, page # 7
# Error on phrase: i hate nigger, page # 8
# Error on phrase: i hate nigger, page # 9
# Error on phrase: i hate nigger, page # 10
# Search Results Found for i hate all nigger: page # 1
# Error on phrase: i hate all nigger, page # 2
# Error on phrase: i hate all nigger, page # 3
# Error on phrase: i hate all nigger, page # 4
# Error on phrase: i hate all nigger, page # 5
# Error on phrase: i hate all nigger, page # 6
# Error on phrase: i hate all nigger, page # 7
# Error on phrase: i hate all nigger, page # 8
# Error on phrase: i hate all nigger, page # 9
# Error on phrase: i hate all nigger, page # 10
# Search Results Found for down with the nigger: page # 1
# Error on phrase: down with the nigger, page # 2
# Error on phrase: down with the nigger, page # 3
# Error on phrase: down with the nigger, page # 4
# Error on phrase: down with the nigger, page # 5
# Error on phrase: down with the nigger, page # 6
# Error on phrase: down with the nigger, page # 7
# Error on phrase: down with the nigger, page # 8
# Error on phrase: down with the nigger, page # 9
# Error on phrase: down with the nigger, page # 10
# Error on phrase: jigaboo people are, page # 1
# Error on phrase: jigaboo people are, page # 2
# Error on phrase: jigaboo people are, page # 3
# Error on phrase: jigaboo people are, page # 4
# Error on phrase: jigaboo people are, page # 5
# Error on phrase: jigaboo people are, page # 6
# Error on phrase: jigaboo people are, page # 7
# Error on phrase: jigaboo people are, page # 8
# Error on phrase: jigaboo people are, page # 9
# Error on phrase: jigaboo people are, page # 10
# Search Results Found for jigaboo are: page # 1
# Error on phrase: jigaboo are, page # 2
# Error on phrase: jigaboo are, page # 3
# Error on phrase: jigaboo are, page # 4
# Error on phrase: jigaboo are, page # 5
# Error on phrase: jigaboo are, page # 6
# Error on phrase: jigaboo are, page # 7
# Error on phrase: jigaboo are, page # 8
# Error on phrase: jigaboo are, page # 9
# Error on phrase: jigaboo are, page # 10
# Error on phrase: all jigaboo are, page # 1
# Error on phrase: all jigaboo are, page # 2
# Error on phrase: all jigaboo are, page # 3
# Error on phrase: all jigaboo are, page # 4
# Error on phrase: all jigaboo are, page # 5
# Error on phrase: all jigaboo are, page # 6
# Error on phrase: all jigaboo are, page # 7
# Error on phrase: all jigaboo are, page # 8
# Error on phrase: all jigaboo are, page # 9
# Error on phrase: all jigaboo are, page # 10
# Search Results Found for i hate jigaboo: page # 1
# Error on phrase: i hate jigaboo, page # 2
# Error on phrase: i hate jigaboo, page # 3
# Error on phrase: i hate jigaboo, page # 4
# Error on phrase: i hate jigaboo, page # 5
# Error on phrase: i hate jigaboo, page # 6
# Error on phrase: i hate jigaboo, page # 7
# Error on phrase: i hate jigaboo, page # 8
# Error on phrase: i hate jigaboo, page # 9
# Error on phrase: i hate jigaboo, page # 10
# Error on phrase: i hate all jigaboo, page # 1
# Error on phrase: i hate all jigaboo, page # 2
# Error on phrase: i hate all jigaboo, page # 3
# Error on phrase: i hate all jigaboo, page # 4
# Error on phrase: i hate all jigaboo, page # 5
# Error on phrase: i hate all jigaboo, page # 6
# Error on phrase: i hate all jigaboo, page # 7
# Error on phrase: i hate all jigaboo, page # 8
# Error on phrase: i hate all jigaboo, page # 9
# Error on phrase: i hate all jigaboo, page # 10
# Error on phrase: down with the jigaboo, page # 1
# Error on phrase: down with the jigaboo, page # 2
# Error on phrase: down with the jigaboo, page # 3
# Error on phrase: down with the jigaboo, page # 4
# Error on phrase: down with the jigaboo, page # 5
# Error on phrase: down with the jigaboo, page # 6
# Error on phrase: down with the jigaboo, page # 7
# Error on phrase: down with the jigaboo, page # 8
# Error on phrase: down with the jigaboo, page # 9
# Error on phrase: down with the jigaboo, page # 10
# Rate limit reached. Sleeping for: 782
# Search Results Found for coon people are: page # 1
# Error on phrase: coon people are, page # 2
# Error on phrase: coon people are, page # 3
# Error on phrase: coon people are, page # 4
# Error on phrase: coon people are, page # 5
# Error on phrase: coon people are, page # 6
# Error on phrase: coon people are, page # 7
# Error on phrase: coon people are, page # 8
# Error on phrase: coon people are, page # 9
# Error on phrase: coon people are, page # 10
# Search Results Found for coon are: page # 1
# Search Results Found for coon are: page # 2
# Search Results Found for coon are: page # 3
# Search Results Found for coon are: page # 4
# Search Results Found for coon are: page # 5
# Error on phrase: coon are, page # 6
# Error on phrase: coon are, page # 7
# Error on phrase: coon are, page # 8
# Error on phrase: coon are, page # 9
# Error on phrase: coon are, page # 10
# Search Results Found for all coon are: page # 1
# Error on phrase: all coon are, page # 2
# Error on phrase: all coon are, page # 3
# Error on phrase: all coon are, page # 4
# Error on phrase: all coon are, page # 5
# Error on phrase: all coon are, page # 6
# Error on phrase: all coon are, page # 7
# Error on phrase: all coon are, page # 8
# Error on phrase: all coon are, page # 9
# Error on phrase: all coon are, page # 10
# Search Results Found for i hate coon: page # 1
# Error on phrase: i hate coon, page # 2
# Error on phrase: i hate coon, page # 3
# Error on phrase: i hate coon, page # 4
# Error on phrase: i hate coon, page # 5
# Error on phrase: i hate coon, page # 6
# Error on phrase: i hate coon, page # 7
# Error on phrase: i hate coon, page # 8
# Error on phrase: i hate coon, page # 9
# Error on phrase: i hate coon, page # 10
# Search Results Found for i hate all coon: page # 1
# Error on phrase: i hate all coon, page # 2
# Error on phrase: i hate all coon, page # 3
# Error on phrase: i hate all coon, page # 4
# Error on phrase: i hate all coon, page # 5
# Error on phrase: i hate all coon, page # 6
# Error on phrase: i hate all coon, page # 7
# Error on phrase: i hate all coon, page # 8
# Error on phrase: i hate all coon, page # 9
# Error on phrase: i hate all coon, page # 10
# Search Results Found for down with the coon: page # 1
# Error on phrase: down with the coon, page # 2
# Error on phrase: down with the coon, page # 3
# Error on phrase: down with the coon, page # 4
# Error on phrase: down with the coon, page # 5
# Error on phrase: down with the coon, page # 6
# Error on phrase: down with the coon, page # 7
# Error on phrase: down with the coon, page # 8
# Error on phrase: down with the coon, page # 9
# Error on phrase: down with the coon, page # 10
# Search Results Found for spook people are: page # 1
# Error on phrase: spook people are, page # 2
# Error on phrase: spook people are, page # 3
# Error on phrase: spook people are, page # 4
# Error on phrase: spook people are, page # 5
# Error on phrase: spook people are, page # 6
# Error on phrase: spook people are, page # 7
# Error on phrase: spook people are, page # 8
# Error on phrase: spook people are, page # 9
# Error on phrase: spook people are, page # 10
# Search Results Found for spook are: page # 1
# Search Results Found for spook are: page # 2
# Search Results Found for spook are: page # 3
# Search Results Found for spook are: page # 4
# Search Results Found for spook are: page # 5
# Error on phrase: spook are, page # 6
# Error on phrase: spook are, page # 7
# Error on phrase: spook are, page # 8
# Error on phrase: spook are, page # 9
# Error on phrase: spook are, page # 10
# Search Results Found for all spook are: page # 1
# Error on phrase: all spook are, page # 2
# Error on phrase: all spook are, page # 3
# Error on phrase: all spook are, page # 4
# Error on phrase: all spook are, page # 5
# Error on phrase: all spook are, page # 6
# Error on phrase: all spook are, page # 7
# Error on phrase: all spook are, page # 8
# Error on phrase: all spook are, page # 9
# Error on phrase: all spook are, page # 10
# Search Results Found for i hate spook: page # 1
# Error on phrase: i hate spook, page # 2
# Error on phrase: i hate spook, page # 3
# Error on phrase: i hate spook, page # 4
# Error on phrase: i hate spook, page # 5
# Error on phrase: i hate spook, page # 6
# Error on phrase: i hate spook, page # 7
# Error on phrase: i hate spook, page # 8
# Error on phrase: i hate spook, page # 9
# Error on phrase: i hate spook, page # 10
# Error on phrase: i hate all spook, page # 1
# Error on phrase: i hate all spook, page # 2
# Error on phrase: i hate all spook, page # 3
# Error on phrase: i hate all spook, page # 4
# Error on phrase: i hate all spook, page # 5
# Error on phrase: i hate all spook, page # 6
# Error on phrase: i hate all spook, page # 7
# Error on phrase: i hate all spook, page # 8
# Error on phrase: i hate all spook, page # 9
# Error on phrase: i hate all spook, page # 10
# Search Results Found for down with the spook: page # 1
# Error on phrase: down with the spook, page # 2
# Error on phrase: down with the spook, page # 3
# Error on phrase: down with the spook, page # 4
# Error on phrase: down with the spook, page # 5
# Error on phrase: down with the spook, page # 6
# Error on phrase: down with the spook, page # 7
# Error on phrase: down with the spook, page # 8
# Error on phrase: down with the spook, page # 9
# Error on phrase: down with the spook, page # 10
# Error on phrase: porch monkey people are, page # 1
# Error on phrase: porch monkey people are, page # 2
# Error on phrase: porch monkey people are, page # 3
# Error on phrase: porch monkey people are, page # 4
# Error on phrase: porch monkey people are, page # 5
# Error on phrase: porch monkey people are, page # 6
# Error on phrase: porch monkey people are, page # 7
# Error on phrase: porch monkey people are, page # 8
# Error on phrase: porch monkey people are, page # 9
# Error on phrase: porch monkey people are, page # 10
# Search Results Found for porch monkey are: page # 1
# Error on phrase: porch monkey are, page # 2
# Error on phrase: porch monkey are, page # 3
# Error on phrase: porch monkey are, page # 4
# Error on phrase: porch monkey are, page # 5
# Error on phrase: porch monkey are, page # 6
# Error on phrase: porch monkey are, page # 7
# Error on phrase: porch monkey are, page # 8
# Error on phrase: porch monkey are, page # 9
# Error on phrase: porch monkey are, page # 10
# Error on phrase: all porch monkey are, page # 1
# Error on phrase: all porch monkey are, page # 2
# Error on phrase: all porch monkey are, page # 3
# Error on phrase: all porch monkey are, page # 4
# Error on phrase: all porch monkey are, page # 5
# Error on phrase: all porch monkey are, page # 6
# Error on phrase: all porch monkey are, page # 7
# Error on phrase: all porch monkey are, page # 8
# Error on phrase: all porch monkey are, page # 9
# Error on phrase: all porch monkey are, page # 10
# Error on phrase: i hate porch monkey, page # 1
# Error on phrase: i hate porch monkey, page # 2
# Error on phrase: i hate porch monkey, page # 3
# Error on phrase: i hate porch monkey, page # 4
# Error on phrase: i hate porch monkey, page # 5
# Error on phrase: i hate porch monkey, page # 6
# Error on phrase: i hate porch monkey, page # 7
# Error on phrase: i hate porch monkey, page # 8
# Error on phrase: i hate porch monkey, page # 9
# Error on phrase: i hate porch monkey, page # 10
# Error on phrase: i hate all porch monkey, page # 1
# Error on phrase: i hate all porch monkey, page # 2
# Error on phrase: i hate all porch monkey, page # 3
# Error on phrase: i hate all porch monkey, page # 4
# Error on phrase: i hate all porch monkey, page # 5
# Error on phrase: i hate all porch monkey, page # 6
# Error on phrase: i hate all porch monkey, page # 7
# Error on phrase: i hate all porch monkey, page # 8
# Error on phrase: i hate all porch monkey, page # 9
# Error on phrase: i hate all porch monkey, page # 10
# Error on phrase: down with the porch monkey, page # 1
# Error on phrase: down with the porch monkey, page # 2
# Error on phrase: down with the porch monkey, page # 3
# Error on phrase: down with the porch monkey, page # 4
# Error on phrase: down with the porch monkey, page # 5
# Error on phrase: down with the porch monkey, page # 6
# Error on phrase: down with the porch monkey, page # 7
# Error on phrase: down with the porch monkey, page # 8
# Error on phrase: down with the porch monkey, page # 9
# Error on phrase: down with the porch monkey, page # 10
# Rate limit reached. Sleeping for: 839
# Search Results Found for spade people are: page # 1
# Error on phrase: spade people are, page # 2
# Error on phrase: spade people are, page # 3
# Error on phrase: spade people are, page # 4
# Error on phrase: spade people are, page # 5
# Error on phrase: spade people are, page # 6
# Error on phrase: spade people are, page # 7
# Error on phrase: spade people are, page # 8
# Error on phrase: spade people are, page # 9
# Error on phrase: spade people are, page # 10
# Search Results Found for spade are: page # 1
# Search Results Found for spade are: page # 2
# Search Results Found for spade are: page # 3
# Error on phrase: spade are, page # 4
# Error on phrase: spade are, page # 5
# Error on phrase: spade are, page # 6
# Error on phrase: spade are, page # 7
# Error on phrase: spade are, page # 8
# Error on phrase: spade are, page # 9
# Error on phrase: spade are, page # 10
# Search Results Found for all spade are: page # 1
# Error on phrase: all spade are, page # 2
# Error on phrase: all spade are, page # 3
# Error on phrase: all spade are, page # 4
# Error on phrase: all spade are, page # 5
# Error on phrase: all spade are, page # 6
# Error on phrase: all spade are, page # 7
# Error on phrase: all spade are, page # 8
# Error on phrase: all spade are, page # 9
# Error on phrase: all spade are, page # 10
# Search Results Found for i hate spade: page # 1
# Error on phrase: i hate spade, page # 2
# Error on phrase: i hate spade, page # 3
# Error on phrase: i hate spade, page # 4
# Error on phrase: i hate spade, page # 5
# Error on phrase: i hate spade, page # 6
# Error on phrase: i hate spade, page # 7
# Error on phrase: i hate spade, page # 8
# Error on phrase: i hate spade, page # 9
# Error on phrase: i hate spade, page # 10
# Search Results Found for i hate all spade: page # 1
# Error on phrase: i hate all spade, page # 2
# Error on phrase: i hate all spade, page # 3
# Error on phrase: i hate all spade, page # 4
# Error on phrase: i hate all spade, page # 5
# Error on phrase: i hate all spade, page # 6
# Error on phrase: i hate all spade, page # 7
# Error on phrase: i hate all spade, page # 8
# Error on phrase: i hate all spade, page # 9
# Error on phrase: i hate all spade, page # 10
# Error on phrase: down with the spade, page # 1
# Error on phrase: down with the spade, page # 2
# Error on phrase: down with the spade, page # 3
# Error on phrase: down with the spade, page # 4
# Error on phrase: down with the spade, page # 5
# Error on phrase: down with the spade, page # 6
# Error on phrase: down with the spade, page # 7
# Error on phrase: down with the spade, page # 8
# Error on phrase: down with the spade, page # 9
# Error on phrase: down with the spade, page # 10
# Error on phrase: black people are, page # 1
# Error on phrase: black people are, page # 2
# Error on phrase: black people are, page # 3
# Error on phrase: black people are, page # 4
# Error on phrase: black people are, page # 5
# Error on phrase: black people are, page # 6
# Error on phrase: black people are, page # 7
# Error on phrase: black people are, page # 8
# Error on phrase: black people are, page # 9
# Error on phrase: black people are, page # 10
# Search Results Found for black are: page # 1
# Search Results Found for black are: page # 2
# Search Results Found for black are: page # 3
# Search Results Found for black are: page # 4
# Search Results Found for black are: page # 5
# Search Results Found for black are: page # 6
# Search Results Found for black are: page # 7
# Search Results Found for black are: page # 8
# Search Results Found for black are: page # 9
# Search Results Found for black are: page # 10
# Search Results Found for all black are: page # 1
# Search Results Found for all black are: page # 2
# Search Results Found for all black are: page # 3
# Search Results Found for all black are: page # 4
# Search Results Found for all black are: page # 5
# Search Results Found for all black are: page # 6
# Search Results Found for all black are: page # 7
# Search Results Found for all black are: page # 8
# Search Results Found for all black are: page # 9
# Search Results Found for all black are: page # 10
# Search Results Found for i hate black: page # 1
# Search Results Found for i hate black: page # 2
# Search Results Found for i hate black: page # 3
# Search Results Found for i hate black: page # 4
# Error on phrase: i hate black, page # 5
# Error on phrase: i hate black, page # 6
# Error on phrase: i hate black, page # 7
# Error on phrase: i hate black, page # 8
# Error on phrase: i hate black, page # 9
# Error on phrase: i hate black, page # 10
# Search Results Found for i hate all black: page # 1
# Error on phrase: i hate all black, page # 2
# Error on phrase: i hate all black, page # 3
# Error on phrase: i hate all black, page # 4
# Error on phrase: i hate all black, page # 5
# Error on phrase: i hate all black, page # 6
# Error on phrase: i hate all black, page # 7
# Error on phrase: i hate all black, page # 8
# Error on phrase: i hate all black, page # 9
# Error on phrase: i hate all black, page # 10
# Search Results Found for down with the black: page # 1
# Error on phrase: down with the black, page # 2
# Error on phrase: down with the black, page # 3
# Error on phrase: down with the black, page # 4
# Error on phrase: down with the black, page # 5
# Error on phrase: down with the black, page # 6
# Error on phrase: down with the black, page # 7
# Error on phrase: down with the black, page # 8
# Error on phrase: down with the black, page # 9
# Error on phrase: down with the black, page # 10
# Search Results Found for nigger people are: page # 1
# Error on phrase: nigger people are, page # 2
# Error on phrase: nigger people are, page # 3
# Error on phrase: nigger people are, page # 4
# Error on phrase: nigger people are, page # 5
# Error on phrase: nigger people are, page # 6
# Error on phrase: nigger people are, page # 7
# Error on phrase: nigger people are, page # 8
# Error on phrase: nigger people are, page # 9
# Error on phrase: nigger people are, page # 10
# Error on phrase: nigger are, page # 1
# Error on phrase: nigger are, page # 2
# Error on phrase: nigger are, page # 3
# Error on phrase: nigger are, page # 4
# Error on phrase: nigger are, page # 5
# Error on phrase: nigger are, page # 6
# Error on phrase: nigger are, page # 7
# Error on phrase: nigger are, page # 8
# Error on phrase: nigger are, page # 9
# Error on phrase: nigger are, page # 10
# Search Results Found for all nigger are: page # 1
# Error on phrase: all nigger are, page # 2
# Error on phrase: all nigger are, page # 3
# Error on phrase: all nigger are, page # 4
# Error on phrase: all nigger are, page # 5
# Error on phrase: all nigger are, page # 6
# Error on phrase: all nigger are, page # 7
# Error on phrase: all nigger are, page # 8
# Error on phrase: all nigger are, page # 9
# Error on phrase: all nigger are, page # 10
# Search Results Found for i hate nigger: page # 1
# Error on phrase: i hate nigger, page # 2
# Error on phrase: i hate nigger, page # 3
# Error on phrase: i hate nigger, page # 4
# Error on phrase: i hate nigger, page # 5
# Error on phrase: i hate nigger, page # 6
# Error on phrase: i hate nigger, page # 7
# Error on phrase: i hate nigger, page # 8
# Error on phrase: i hate nigger, page # 9
# Error on phrase: i hate nigger, page # 10
# Search Results Found for i hate all nigger: page # 1
# Error on phrase: i hate all nigger, page # 2
# Error on phrase: i hate all nigger, page # 3
# Error on phrase: i hate all nigger, page # 4
# Error on phrase: i hate all nigger, page # 5
# Error on phrase: i hate all nigger, page # 6
# Error on phrase: i hate all nigger, page # 7
# Error on phrase: i hate all nigger, page # 8
# Error on phrase: i hate all nigger, page # 9
# Error on phrase: i hate all nigger, page # 10
# Search Results Found for down with the nigger: page # 1
# Error on phrase: down with the nigger, page # 2
# Error on phrase: down with the nigger, page # 3
# Error on phrase: down with the nigger, page # 4
# Error on phrase: down with the nigger, page # 5
# Error on phrase: down with the nigger, page # 6
# Error on phrase: down with the nigger, page # 7
# Error on phrase: down with the nigger, page # 8
# Error on phrase: down with the nigger, page # 9
# Error on phrase: down with the nigger, page # 10
# Rate limit reached. Sleeping for: 791
# Error on phrase: jigaboo people are, page # 1
# Error on phrase: jigaboo people are, page # 2
# Error on phrase: jigaboo people are, page # 3
# Error on phrase: jigaboo people are, page # 4
# Error on phrase: jigaboo people are, page # 5
# Error on phrase: jigaboo people are, page # 6
# Error on phrase: jigaboo people are, page # 7
# Error on phrase: jigaboo people are, page # 8
# Error on phrase: jigaboo people are, page # 9
# Error on phrase: jigaboo people are, page # 10
# Search Results Found for jigaboo are: page # 1
# Error on phrase: jigaboo are, page # 2
# Error on phrase: jigaboo are, page # 3
# Error on phrase: jigaboo are, page # 4
# Error on phrase: jigaboo are, page # 5
# Error on phrase: jigaboo are, page # 6
# Error on phrase: jigaboo are, page # 7
# Error on phrase: jigaboo are, page # 8
# Error on phrase: jigaboo are, page # 9
# Error on phrase: jigaboo are, page # 10
# Error on phrase: all jigaboo are, page # 1
# Error on phrase: all jigaboo are, page # 2
# Error on phrase: all jigaboo are, page # 3
# Error on phrase: all jigaboo are, page # 4
# Error on phrase: all jigaboo are, page # 5
# Error on phrase: all jigaboo are, page # 6
# Error on phrase: all jigaboo are, page # 7
# Error on phrase: all jigaboo are, page # 8
# Error on phrase: all jigaboo are, page # 9
# Error on phrase: all jigaboo are, page # 10
# Search Results Found for i hate jigaboo: page # 1
# Error on phrase: i hate jigaboo, page # 2
# Error on phrase: i hate jigaboo, page # 3
# Error on phrase: i hate jigaboo, page # 4
# Error on phrase: i hate jigaboo, page # 5
# Error on phrase: i hate jigaboo, page # 6
# Error on phrase: i hate jigaboo, page # 7
# Error on phrase: i hate jigaboo, page # 8
# Error on phrase: i hate jigaboo, page # 9
# Error on phrase: i hate jigaboo, page # 10
# Error on phrase: i hate all jigaboo, page # 1
# Error on phrase: i hate all jigaboo, page # 2
# Error on phrase: i hate all jigaboo, page # 3
# Error on phrase: i hate all jigaboo, page # 4
# Error on phrase: i hate all jigaboo, page # 5
# Error on phrase: i hate all jigaboo, page # 6
# Error on phrase: i hate all jigaboo, page # 7
# Error on phrase: i hate all jigaboo, page # 8
# Error on phrase: i hate all jigaboo, page # 9
# Error on phrase: i hate all jigaboo, page # 10
# Error on phrase: down with the jigaboo, page # 1
# Error on phrase: down with the jigaboo, page # 2
# Error on phrase: down with the jigaboo, page # 3
# Error on phrase: down with the jigaboo, page # 4
# Error on phrase: down with the jigaboo, page # 5
# Error on phrase: down with the jigaboo, page # 6
# Error on phrase: down with the jigaboo, page # 7
# Error on phrase: down with the jigaboo, page # 8
# Error on phrase: down with the jigaboo, page # 9
# Error on phrase: down with the jigaboo, page # 10
# Search Results Found for coon people are: page # 1
# Error on phrase: coon people are, page # 2
# Error on phrase: coon people are, page # 3
# Error on phrase: coon people are, page # 4
# Error on phrase: coon people are, page # 5
# Error on phrase: coon people are, page # 6
# Error on phrase: coon people are, page # 7
# Error on phrase: coon people are, page # 8
# Error on phrase: coon people are, page # 9
# Error on phrase: coon people are, page # 10
# Search Results Found for coon are: page # 1
# Search Results Found for coon are: page # 2
# Search Results Found for coon are: page # 3
# Search Results Found for coon are: page # 4
# Search Results Found for coon are: page # 5
# Error on phrase: coon are, page # 6
# Error on phrase: coon are, page # 7
# Error on phrase: coon are, page # 8
# Error on phrase: coon are, page # 9
# Error on phrase: coon are, page # 10
# Search Results Found for all coon are: page # 1
# Error on phrase: all coon are, page # 2
# Error on phrase: all coon are, page # 3
# Error on phrase: all coon are, page # 4
# Error on phrase: all coon are, page # 5
# Error on phrase: all coon are, page # 6
# Error on phrase: all coon are, page # 7
# Error on phrase: all coon are, page # 8
# Error on phrase: all coon are, page # 9
# Error on phrase: all coon are, page # 10
# Search Results Found for i hate coon: page # 1
# Error on phrase: i hate coon, page # 2
# Error on phrase: i hate coon, page # 3
# Error on phrase: i hate coon, page # 4
# Error on phrase: i hate coon, page # 5
# Error on phrase: i hate coon, page # 6
# Error on phrase: i hate coon, page # 7
# Error on phrase: i hate coon, page # 8
# Error on phrase: i hate coon, page # 9
# Error on phrase: i hate coon, page # 10
# Search Results Found for i hate all coon: page # 1
# Error on phrase: i hate all coon, page # 2
# Error on phrase: i hate all coon, page # 3
# Error on phrase: i hate all coon, page # 4
# Error on phrase: i hate all coon, page # 5
# Error on phrase: i hate all coon, page # 6
# Error on phrase: i hate all coon, page # 7
# Error on phrase: i hate all coon, page # 8
# Error on phrase: i hate all coon, page # 9
# Error on phrase: i hate all coon, page # 10
# Search Results Found for down with the coon: page # 1
# Error on phrase: down with the coon, page # 2
# Error on phrase: down with the coon, page # 3
# Error on phrase: down with the coon, page # 4
# Error on phrase: down with the coon, page # 5
# Error on phrase: down with the coon, page # 6
# Error on phrase: down with the coon, page # 7
# Error on phrase: down with the coon, page # 8
# Error on phrase: down with the coon, page # 9
# Error on phrase: down with the coon, page # 10
# Search Results Found for spook people are: page # 1
# Error on phrase: spook people are, page # 2
# Error on phrase: spook people are, page # 3
# Error on phrase: spook people are, page # 4
# Error on phrase: spook people are, page # 5
# Error on phrase: spook people are, page # 6
# Error on phrase: spook people are, page # 7
# Error on phrase: spook people are, page # 8
# Error on phrase: spook people are, page # 9
# Error on phrase: spook people are, page # 10
# Search Results Found for spook are: page # 1
# Search Results Found for spook are: page # 2
# Search Results Found for spook are: page # 3
# Search Results Found for spook are: page # 4
# Search Results Found for spook are: page # 5
# Error on phrase: spook are, page # 6
# Error on phrase: spook are, page # 7
# Error on phrase: spook are, page # 8
# Error on phrase: spook are, page # 9
# Error on phrase: spook are, page # 10
# Search Results Found for all spook are: page # 1
# Error on phrase: all spook are, page # 2
# Error on phrase: all spook are, page # 3
# Error on phrase: all spook are, page # 4
# Error on phrase: all spook are, page # 5
# Error on phrase: all spook are, page # 6
# Error on phrase: all spook are, page # 7
# Error on phrase: all spook are, page # 8
# Error on phrase: all spook are, page # 9
# Error on phrase: all spook are, page # 10
# Search Results Found for i hate spook: page # 1
# Error on phrase: i hate spook, page # 2
# Error on phrase: i hate spook, page # 3
# Error on phrase: i hate spook, page # 4
# Error on phrase: i hate spook, page # 5
# Error on phrase: i hate spook, page # 6
# Error on phrase: i hate spook, page # 7
# Error on phrase: i hate spook, page # 8
# Error on phrase: i hate spook, page # 9
# Error on phrase: i hate spook, page # 10
# Error on phrase: i hate all spook, page # 1
# Error on phrase: i hate all spook, page # 2
# Error on phrase: i hate all spook, page # 3
# Error on phrase: i hate all spook, page # 4
# Error on phrase: i hate all spook, page # 5
# Error on phrase: i hate all spook, page # 6
# Error on phrase: i hate all spook, page # 7
# Error on phrase: i hate all spook, page # 8
# Error on phrase: i hate all spook, page # 9
# Error on phrase: i hate all spook, page # 10
# Search Results Found for down with the spook: page # 1
# Error on phrase: down with the spook, page # 2
# Error on phrase: down with the spook, page # 3
# Error on phrase: down with the spook, page # 4
# Error on phrase: down with the spook, page # 5
# Error on phrase: down with the spook, page # 6
# Error on phrase: down with the spook, page # 7
# Error on phrase: down with the spook, page # 8
# Error on phrase: down with the spook, page # 9
# Error on phrase: down with the spook, page # 10
# Rate limit reached. Sleeping for: 833
# Error on phrase: porch monkey people are, page # 1
# Error on phrase: porch monkey people are, page # 2
# Error on phrase: porch monkey people are, page # 3
# Error on phrase: porch monkey people are, page # 4
# Error on phrase: porch monkey people are, page # 5
# Error on phrase: porch monkey people are, page # 6
# Error on phrase: porch monkey people are, page # 7
# Error on phrase: porch monkey people are, page # 8
# Error on phrase: porch monkey people are, page # 9
# Error on phrase: porch monkey people are, page # 10
# Search Results Found for porch monkey are: page # 1
# Error on phrase: porch monkey are, page # 2
# Error on phrase: porch monkey are, page # 3
# Error on phrase: porch monkey are, page # 4
# Error on phrase: porch monkey are, page # 5
# Error on phrase: porch monkey are, page # 6
# Error on phrase: porch monkey are, page # 7
# Error on phrase: porch monkey are, page # 8
# Error on phrase: porch monkey are, page # 9
# Error on phrase: porch monkey are, page # 10
# Error on phrase: all porch monkey are, page # 1
# Error on phrase: all porch monkey are, page # 2
# Error on phrase: all porch monkey are, page # 3
# Error on phrase: all porch monkey are, page # 4
# Error on phrase: all porch monkey are, page # 5
# Error on phrase: all porch monkey are, page # 6
# Error on phrase: all porch monkey are, page # 7
# Error on phrase: all porch monkey are, page # 8
# Error on phrase: all porch monkey are, page # 9
# Error on phrase: all porch monkey are, page # 10
# Error on phrase: i hate porch monkey, page # 1
# Error on phrase: i hate porch monkey, page # 2
# Error on phrase: i hate porch monkey, page # 3
# Error on phrase: i hate porch monkey, page # 4
# Error on phrase: i hate porch monkey, page # 5
# Error on phrase: i hate porch monkey, page # 6
# Error on phrase: i hate porch monkey, page # 7
# Error on phrase: i hate porch monkey, page # 8
# Error on phrase: i hate porch monkey, page # 9
# Error on phrase: i hate porch monkey, page # 10
# Error on phrase: i hate all porch monkey, page # 1
# Error on phrase: i hate all porch monkey, page # 2
# Error on phrase: i hate all porch monkey, page # 3
# Error on phrase: i hate all porch monkey, page # 4
# Error on phrase: i hate all porch monkey, page # 5
# Error on phrase: i hate all porch monkey, page # 6
# Error on phrase: i hate all porch monkey, page # 7
# Error on phrase: i hate all porch monkey, page # 8
# Error on phrase: i hate all porch monkey, page # 9
# Error on phrase: i hate all porch monkey, page # 10
# Error on phrase: down with the porch monkey, page # 1
# Error on phrase: down with the porch monkey, page # 2
# Error on phrase: down with the porch monkey, page # 3
# Error on phrase: down with the porch monkey, page # 4
# Error on phrase: down with the porch monkey, page # 5
# Error on phrase: down with the porch monkey, page # 6
# Error on phrase: down with the porch monkey, page # 7
# Error on phrase: down with the porch monkey, page # 8
# Error on phrase: down with the porch monkey, page # 9
# Error on phrase: down with the porch monkey, page # 10
# Search Results Found for spade people are: page # 1
# Error on phrase: spade people are, page # 2
# Error on phrase: spade people are, page # 3
# Error on phrase: spade people are, page # 4
# Error on phrase: spade people are, page # 5
# Error on phrase: spade people are, page # 6
# Error on phrase: spade people are, page # 7
# Error on phrase: spade people are, page # 8
# Error on phrase: spade people are, page # 9
# Error on phrase: spade people are, page # 10
# Search Results Found for spade are: page # 1
# Search Results Found for spade are: page # 2
# Search Results Found for spade are: page # 3
# Error on phrase: spade are, page # 4
# Error on phrase: spade are, page # 5
# Error on phrase: spade are, page # 6
# Error on phrase: spade are, page # 7
# Error on phrase: spade are, page # 8
# Error on phrase: spade are, page # 9
# Error on phrase: spade are, page # 10
# Search Results Found for all spade are: page # 1
# Error on phrase: all spade are, page # 2
# Error on phrase: all spade are, page # 3
# Error on phrase: all spade are, page # 4
# Error on phrase: all spade are, page # 5
# Error on phrase: all spade are, page # 6
# Error on phrase: all spade are, page # 7
# Error on phrase: all spade are, page # 8
# Error on phrase: all spade are, page # 9
# Error on phrase: all spade are, page # 10
# Search Results Found for i hate spade: page # 1
# Error on phrase: i hate spade, page # 2
# Error on phrase: i hate spade, page # 3
# Error on phrase: i hate spade, page # 4
# Error on phrase: i hate spade, page # 5
# Error on phrase: i hate spade, page # 6
# Error on phrase: i hate spade, page # 7
# Error on phrase: i hate spade, page # 8
# Error on phrase: i hate spade, page # 9
# Error on phrase: i hate spade, page # 10
# Search Results Found for i hate all spade: page # 1
# Error on phrase: i hate all spade, page # 2
# Error on phrase: i hate all spade, page # 3
# Error on phrase: i hate all spade, page # 4
# Error on phrase: i hate all spade, page # 5
# Error on phrase: i hate all spade, page # 6
# Error on phrase: i hate all spade, page # 7
# Error on phrase: i hate all spade, page # 8
# Error on phrase: i hate all spade, page # 9
# Error on phrase: i hate all spade, page # 10
# Error on phrase: down with the spade, page # 1
# Error on phrase: down with the spade, page # 2
# Error on phrase: down with the spade, page # 3
# Error on phrase: down with the spade, page # 4
# Error on phrase: down with the spade, page # 5
# Error on phrase: down with the spade, page # 6
# Error on phrase: down with the spade, page # 7
# Error on phrase: down with the spade, page # 8
# Error on phrase: down with the spade, page # 9
# Error on phrase: down with the spade, page # 10
# Search Results Found for jews people are: page # 1
# Search Results Found for jews people are: page # 2
# Search Results Found for jews people are: page # 3
# Search Results Found for jews people are: page # 4
# Search Results Found for jews people are: page # 5
# Search Results Found for jews people are: page # 6
# Search Results Found for jews people are: page # 7
# Search Results Found for jews people are: page # 8
# Search Results Found for jews people are: page # 9
# Search Results Found for jews people are: page # 10
# Error on phrase: jews are, page # 1
# Error on phrase: jews are, page # 2
# Error on phrase: jews are, page # 3
# Error on phrase: jews are, page # 4
# Error on phrase: jews are, page # 5
# Error on phrase: jews are, page # 6
# Error on phrase: jews are, page # 7
# Error on phrase: jews are, page # 8
# Error on phrase: jews are, page # 9
# Error on phrase: jews are, page # 10
# Error on phrase: all jews are, page # 1
# Error on phrase: all jews are, page # 2
# Error on phrase: all jews are, page # 3
# Error on phrase: all jews are, page # 4
# Error on phrase: all jews are, page # 5
# Error on phrase: all jews are, page # 6
# Error on phrase: all jews are, page # 7
# Error on phrase: all jews are, page # 8
# Error on phrase: all jews are, page # 9
# Error on phrase: all jews are, page # 10
# Error on phrase: i hate jews, page # 1
# Error on phrase: i hate jews, page # 2
# Error on phrase: i hate jews, page # 3
# Error on phrase: i hate jews, page # 4
# Error on phrase: i hate jews, page # 5
# Error on phrase: i hate jews, page # 6
# Error on phrase: i hate jews, page # 7
# Error on phrase: i hate jews, page # 8
# Error on phrase: i hate jews, page # 9
# Error on phrase: i hate jews, page # 10
# Search Results Found for i hate all jews: page # 1
# Error on phrase: i hate all jews, page # 2
# Error on phrase: i hate all jews, page # 3
# Error on phrase: i hate all jews, page # 4
# Error on phrase: i hate all jews, page # 5
# Error on phrase: i hate all jews, page # 6
# Error on phrase: i hate all jews, page # 7
# Error on phrase: i hate all jews, page # 8
# Error on phrase: i hate all jews, page # 9
# Error on phrase: i hate all jews, page # 10
# Search Results Found for down with the jews: page # 1
# Error on phrase: down with the jews, page # 2
# Error on phrase: down with the jews, page # 3
# Error on phrase: down with the jews, page # 4
# Error on phrase: down with the jews, page # 5
# Error on phrase: down with the jews, page # 6
# Error on phrase: down with the jews, page # 7
# Error on phrase: down with the jews, page # 8
# Error on phrase: down with the jews, page # 9
# Error on phrase: down with the jews, page # 10

# %%
import pandas as pd

# %%
racist_df = pd.DataFrame({
    #"race": race_list,
    "phrase": phrase,
    "time": time,
    "tweet": text,
    "# of hastags": num_hashtags,
    "# of mentions": num_user_mentions,
    "screen name": screen_name,
    "user id": user_id,
    "name": name,
    "account creation date": account_creation_time,
    "number of account tweets": user_tweet_count,
    "location": location,
    "# followers": num_followers,
    "# following": num_following,
    "# retweets of tweet": num_retweets,
    "# favorite of tweet": num_favorites,
    "in reply to": in_reply_to
})

# %%
text
# Out:
# []
