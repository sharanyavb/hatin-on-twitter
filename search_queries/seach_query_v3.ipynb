# %%
import tweepy
import json
import keys
from hate_speech1 import race_dict
import pandas as pd

# get keys
consumer_key = "dhdP8LaOYfkxmxi9Fwde6XtNs"
consumer_secret = "52yu7buJCQdZ44f9niYauSg6aXHLqHUKjZVXM8HqPxYooKPWVB"
access_token = "1570660926-Ck2MtiaK9ys8AiyDUBsgL3RV3in8GigvkcUPRAp"
access_token_secret = "765YZYKpMvfK8PDXWUxCa2yxZKnf5auAiASwpLNxYCbGO"

#autheticate
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser(), wait_on_rate_limit = True, wait_on_rate_limit_notify = True)

#data lists
race_list = []
phrase_from_list = []
time = []
text = []
num_hashtags = []
hashtag_list = []
num_user_mentions = []
user_id = []
name = []
screen_name = []
account_creation_time = []
user_tweet_count = []
location = []
num_followers = []
num_following = []
num_retweets = []
num_favorites = []
in_reply_to = []

phrase_list = []

def search_phrase(race):
    for race in race_dict[race]:
        phrase0 = race + ' people are'
        phrase1 = race + ' are'
        phrase2 = 'all ' + race + ' are'
        phrase3 = 'i hate ' + race
        phrase4 = 'i hate all ' + race
        phrase5 = 'down with the ' + race
        phrase_list.append(phrase0)
        phrase_list.append(phrase1)
        phrase_list.append(phrase2)
        phrase_list.append(phrase3)
        phrase_list.append(phrase4)
        phrase_list.append(phrase5)

# def search_phrases(phrase_list):
#         for entry in phrase_list: 
#             print(entry)



def search_request(race_name, search_term):
    page_num = 1
    for x in range(10):
        if x == 0:
            end_id = None
        try: #-filter:retweets   #and (not tweet["retweeted"]) and ("RT" not in tweet["text"]) REMOVE RETWEET DUPLICATES
            response = api.search(search_term, lang = "en", count = 100, max_id = end_id, geocode="39.82,-98.57,1500mi")['statuses']
            for tweet in response:
                tweet_text = tweet['text']
                if ("RT" not in tweet_text) and (search_term in tweet_text): 
                    #print('Success 1')
                    race_list.append(race_name)
                    #print('race name appended')
                    phrase_from_list.append(search_term)
                    #print('search term appended')
                    time.append(tweet['created_at'])
                    #print('time appended')
                    text.append(tweet['text'])
                    #print('text appended')
                    num_hashtags_tweet = len(tweet['entities']['hashtags'])
                    num_hashtags.append(num_hashtags_tweet)
                    hashtags = []
                    if num_hashtags_tweet > 0:
                        for hastag_text in tweet['entities']['hashtags']:
                            hashtags.append(hastag_text['text'])
                    hashtag_list.append(hashtags)
                    num_user_mentions.append(len(tweet['entities']['user_mentions']))
                    user_id.append(tweet['user']['id'])
                    screen_name.append(tweet['user']['screen_name'])
                    name.append(tweet['user']['name'])
                    account_creation_time.append(tweet['user']['created_at'])
                    user_tweet_count.append(tweet['user']['statuses_count'])
                    location.append(tweet['user']['location']) 
                    num_followers.append(tweet['user']['followers_count'])
                    num_following.append(tweet['user']['friends_count'])
                    num_retweets.append(tweet['retweet_count'])
                    num_favorites.append(tweet["favorite_count"])  
                    in_reply_to.append(tweet["in_reply_to_user_id"]) 
                    #print('Success 2!')
            end_id = response[-1]['id'] - 1
            print("Search Results Found for %s: page # %s" % (search_term, page_num))
        except: 
            print('Error on phrase: %s, page # %s' % (search_term, page_num))
            break
        page_num += 1

# for term in black:
#     slur = term.lower()
#     search_request(slur)
#     print("Results for %s: %s" % (term, len(word)))

for key in race_dict.keys():
    #print(key)
    search_phrase(key)
    #print(phrase_list)
    for phrase in phrase_list:
        #print(key, phrase)
        search_request(key, phrase)
    phrase_list = []
    #print(phrase_list)

#search_request('black', 'black are')
# print(location)
# print(race_list)
# for n in text:
#     print(n)
# print(location)
# print(text)


# user_location = []
# profile_location = []
# timezone = []


# def user_location():
#     for name in screen_name:
#         try: #-filter:retweets   #and (not tweet["retweeted"]) and ("RT" not in tweet["text"])
#             response = api.get_user(name)
#             for tweet in response:
#                 user_location.append(response["location"])
#                 profile_location.append(response["profile_location"])
# Out:
# Search Results Found for black people are: page # 1
# Search Results Found for black people are: page # 2
# Search Results Found for black people are: page # 3
# Search Results Found for black people are: page # 4
# Search Results Found for black people are: page # 5
# Search Results Found for black people are: page # 6
# Search Results Found for black people are: page # 7
# Search Results Found for black people are: page # 8
# Search Results Found for black people are: page # 9
# Search Results Found for black people are: page # 10
# Search Results Found for black are: page # 1
# Search Results Found for black are: page # 2
# Search Results Found for black are: page # 3
# Search Results Found for black are: page # 4
# Search Results Found for black are: page # 5
# Search Results Found for black are: page # 6
# Search Results Found for black are: page # 7
# Search Results Found for black are: page # 8
# Search Results Found for black are: page # 9
# Search Results Found for black are: page # 10
# Search Results Found for all black are: page # 1
# Search Results Found for all black are: page # 2
# Search Results Found for all black are: page # 3
# Search Results Found for all black are: page # 4
# Search Results Found for all black are: page # 5
# Search Results Found for all black are: page # 6
# Search Results Found for all black are: page # 7
# Search Results Found for all black are: page # 8
# Search Results Found for all black are: page # 9
# Search Results Found for all black are: page # 10
# Search Results Found for i hate black: page # 1
# Search Results Found for i hate black: page # 2
# Search Results Found for i hate black: page # 3
# Search Results Found for i hate black: page # 4
# Search Results Found for i hate black: page # 5
# Search Results Found for i hate black: page # 6
# Search Results Found for i hate black: page # 7
# Search Results Found for i hate black: page # 8
# Search Results Found for i hate black: page # 9
# Search Results Found for i hate black: page # 10
# Search Results Found for i hate all black: page # 1
# Search Results Found for i hate all black: page # 2
# Search Results Found for i hate all black: page # 3
# Search Results Found for i hate all black: page # 4
# Search Results Found for i hate all black: page # 5
# Error on phrase: i hate all black, page # 6
# Search Results Found for down with the black: page # 1
# Search Results Found for down with the black: page # 2
# Search Results Found for down with the black: page # 3
# Search Results Found for down with the black: page # 4
# Search Results Found for down with the black: page # 5
# Search Results Found for down with the black: page # 6
# Error on phrase: down with the black, page # 7
# Search Results Found for nigger people are: page # 1
# Error on phrase: nigger people are, page # 2
# Search Results Found for nigger are: page # 1
# Search Results Found for nigger are: page # 2
# Search Results Found for nigger are: page # 3
# Search Results Found for nigger are: page # 4
# Search Results Found for nigger are: page # 5
# Error on phrase: nigger are, page # 6
# Search Results Found for all nigger are: page # 1
# Error on phrase: all nigger are, page # 2
# Search Results Found for i hate nigger: page # 1
# Error on phrase: i hate nigger, page # 2
# Search Results Found for i hate all nigger: page # 1
# Error on phrase: i hate all nigger, page # 2
# Search Results Found for down with the nigger: page # 1
# Error on phrase: down with the nigger, page # 2
# Error on phrase: jigaboo people are, page # 1
# Search Results Found for jigaboo are: page # 1
# Error on phrase: jigaboo are, page # 2
# Error on phrase: all jigaboo are, page # 1
# Search Results Found for i hate jigaboo: page # 1
# Error on phrase: i hate jigaboo, page # 2
# Error on phrase: i hate all jigaboo, page # 1
# Error on phrase: down with the jigaboo, page # 1
# Search Results Found for coon people are: page # 1
# Error on phrase: coon people are, page # 2
# Search Results Found for coon are: page # 1
# Search Results Found for coon are: page # 2
# Search Results Found for coon are: page # 3
# Search Results Found for coon are: page # 4
# Search Results Found for coon are: page # 5
# Error on phrase: coon are, page # 6
# Search Results Found for all coon are: page # 1
# Error on phrase: all coon are, page # 2
# Search Results Found for i hate coon: page # 1
# Error on phrase: i hate coon, page # 2
# Search Results Found for i hate all coon: page # 1
# Error on phrase: i hate all coon, page # 2
# Search Results Found for down with the coon: page # 1
# Error on phrase: down with the coon, page # 2
# Search Results Found for spook people are: page # 1
# Error on phrase: spook people are, page # 2
# Search Results Found for spook are: page # 1
# Search Results Found for spook are: page # 2
# Search Results Found for spook are: page # 3
# Search Results Found for spook are: page # 4
# Error on phrase: spook are, page # 5
# Search Results Found for all spook are: page # 1
# Error on phrase: all spook are, page # 2
# Search Results Found for i hate spook: page # 1
# Error on phrase: i hate spook, page # 2
# Error on phrase: i hate all spook, page # 1
# Search Results Found for down with the spook: page # 1
# Error on phrase: down with the spook, page # 2
# Error on phrase: porch monkey people are, page # 1
# Search Results Found for porch monkey are: page # 1
# Error on phrase: porch monkey are, page # 2
# Error on phrase: all porch monkey are, page # 1
# Error on phrase: i hate porch monkey, page # 1
# Error on phrase: i hate all porch monkey, page # 1
# Error on phrase: down with the porch monkey, page # 1
# Search Results Found for spade people are: page # 1
# Error on phrase: spade people are, page # 2
# Search Results Found for spade are: page # 1
# Search Results Found for spade are: page # 2
# Error on phrase: spade are, page # 3
# Search Results Found for all spade are: page # 1
# Error on phrase: all spade are, page # 2
# Search Results Found for i hate spade: page # 1
# Error on phrase: i hate spade, page # 2
# Search Results Found for i hate all spade: page # 1
# Error on phrase: i hate all spade, page # 2
# Error on phrase: down with the spade, page # 1
# Search Results Found for jews people are: page # 1
# Search Results Found for jews people are: page # 2
# Search Results Found for jews people are: page # 3
# Search Results Found for jews people are: page # 4
# Search Results Found for jews people are: page # 5
# Search Results Found for jews people are: page # 6
# Search Results Found for jews people are: page # 7
# Search Results Found for jews people are: page # 8
# Search Results Found for jews people are: page # 9
# Search Results Found for jews people are: page # 10
# Search Results Found for jews are: page # 1
# Search Results Found for jews are: page # 2
# Search Results Found for jews are: page # 3
# Search Results Found for jews are: page # 4
# Search Results Found for jews are: page # 5
# Search Results Found for jews are: page # 6
# Search Results Found for jews are: page # 7
# Search Results Found for jews are: page # 8
# Search Results Found for jews are: page # 9
# Search Results Found for jews are: page # 10
# Search Results Found for all jews are: page # 1
# Search Results Found for all jews are: page # 2
# Search Results Found for all jews are: page # 3
# Search Results Found for all jews are: page # 4
# Search Results Found for all jews are: page # 5
# Search Results Found for all jews are: page # 6
# Search Results Found for all jews are: page # 7
# Search Results Found for all jews are: page # 8
# Search Results Found for all jews are: page # 9
# Search Results Found for all jews are: page # 10
# Search Results Found for i hate jews: page # 1
# Search Results Found for i hate jews: page # 2
# Search Results Found for i hate jews: page # 3
# Search Results Found for i hate jews: page # 4
# Error on phrase: i hate jews, page # 5
# Search Results Found for i hate all jews: page # 1
# Error on phrase: i hate all jews, page # 2
# Search Results Found for down with the jews: page # 1
# Error on phrase: down with the jews, page # 2
# Search Results Found for christ killer people are: page # 1
# Error on phrase: christ killer people are, page # 2
# Search Results Found for christ killer are: page # 1
# Error on phrase: christ killer are, page # 2
# Error on phrase: all christ killer are, page # 1
# Search Results Found for i hate christ killer: page # 1
# Error on phrase: i hate christ killer, page # 2
# Error on phrase: i hate all christ killer, page # 1
# Error on phrase: down with the christ killer, page # 1
# Search Results Found for hebrew people are: page # 1
# Error on phrase: hebrew people are, page # 2
# Search Results Found for hebrew are: page # 1
# Search Results Found for hebrew are: page # 2
# Search Results Found for hebrew are: page # 3
# Search Results Found for hebrew are: page # 4
# Rate limit reached. Sleeping for: 740
# Search Results Found for hebrew are: page # 5
# Search Results Found for hebrew are: page # 6
# Search Results Found for hebrew are: page # 7
# Search Results Found for hebrew are: page # 8
# Search Results Found for hebrew are: page # 9
# Search Results Found for hebrew are: page # 10
# Search Results Found for all hebrew are: page # 1
# Error on phrase: all hebrew are, page # 2
# Search Results Found for i hate hebrew: page # 1
# Error on phrase: i hate hebrew, page # 2
# Error on phrase: i hate all hebrew, page # 1
# Search Results Found for down with the hebrew: page # 1
# Error on phrase: down with the hebrew, page # 2
# Error on phrase: heeb people are, page # 1
# Search Results Found for heeb are: page # 1
# Error on phrase: heeb are, page # 2
# Error on phrase: all heeb are, page # 1
# Error on phrase: i hate heeb, page # 1
# Error on phrase: i hate all heeb, page # 1
# Error on phrase: down with the heeb, page # 1
# Search Results Found for hebe people are: page # 1
# Error on phrase: hebe people are, page # 2
# Search Results Found for hebe are: page # 1
# Error on phrase: hebe are, page # 2
# Search Results Found for all hebe are: page # 1
# Error on phrase: all hebe are, page # 2
# Search Results Found for i hate hebe: page # 1
# Error on phrase: i hate hebe, page # 2
# Error on phrase: i hate all hebe, page # 1
# Error on phrase: down with the hebe, page # 1
# Search Results Found for kike people are: page # 1
# Error on phrase: kike people are, page # 2
# Search Results Found for kike are: page # 1
# Error on phrase: kike are, page # 2
# Search Results Found for all kike are: page # 1
# Error on phrase: all kike are, page # 2
# Search Results Found for i hate kike: page # 1
# Error on phrase: i hate kike, page # 2
# Error on phrase: i hate all kike, page # 1
# Error on phrase: down with the kike, page # 1
# Error on phrase: jew-bag people are, page # 1
# Error on phrase: jew-bag are, page # 1
# Error on phrase: all jew-bag are, page # 1
# Error on phrase: i hate jew-bag, page # 1
# Error on phrase: i hate all jew-bag, page # 1
# Error on phrase: down with the jew-bag, page # 1
# Error on phrase: yid people are, page # 1
# Search Results Found for yid are: page # 1
# Error on phrase: yid are, page # 2
# Error on phrase: all yid are, page # 1
# Error on phrase: i hate yid, page # 1
# Error on phrase: i hate all yid, page # 1
# Error on phrase: down with the yid, page # 1
# Search Results Found for muslim people are: page # 1
# Search Results Found for muslim people are: page # 2
# Search Results Found for muslim people are: page # 3
# Search Results Found for muslim people are: page # 4
# Search Results Found for muslim people are: page # 5
# Search Results Found for muslim people are: page # 6
# Search Results Found for muslim people are: page # 7
# Search Results Found for muslim people are: page # 8
# Search Results Found for muslim people are: page # 9
# Error on phrase: muslim people are, page # 10
# Search Results Found for muslim are: page # 1
# Search Results Found for muslim are: page # 2
# Search Results Found for muslim are: page # 3
# Search Results Found for muslim are: page # 4
# Search Results Found for muslim are: page # 5
# Search Results Found for muslim are: page # 6
# Search Results Found for muslim are: page # 7
# Search Results Found for muslim are: page # 8
# Search Results Found for muslim are: page # 9
# Search Results Found for muslim are: page # 10
# Search Results Found for all muslim are: page # 1
# Search Results Found for all muslim are: page # 2
# Search Results Found for all muslim are: page # 3
# Search Results Found for all muslim are: page # 4
# Search Results Found for all muslim are: page # 5
# Search Results Found for all muslim are: page # 6
# Search Results Found for all muslim are: page # 7
# Search Results Found for all muslim are: page # 8
# Search Results Found for all muslim are: page # 9
# Search Results Found for all muslim are: page # 10
# Search Results Found for i hate muslim: page # 1
# Search Results Found for i hate muslim: page # 2
# Search Results Found for i hate muslim: page # 3
# Search Results Found for i hate muslim: page # 4
# Error on phrase: i hate muslim, page # 5
# Search Results Found for i hate all muslim: page # 1
# Error on phrase: i hate all muslim, page # 2
# Search Results Found for down with the muslim: page # 1
# Error on phrase: down with the muslim, page # 2
# Error on phrase: sand nigger people are, page # 1
# Search Results Found for sand nigger are: page # 1
# Error on phrase: sand nigger are, page # 2
# Error on phrase: all sand nigger are, page # 1
# Error on phrase: i hate sand nigger, page # 1
# Error on phrase: i hate all sand nigger, page # 1
# Error on phrase: down with the sand nigger, page # 1
# Search Results Found for towel head people are: page # 1
# Error on phrase: towel head people are, page # 2
# Search Results Found for towel head are: page # 1
# Error on phrase: towel head are, page # 2
# Search Results Found for all towel head are: page # 1
# Error on phrase: all towel head are, page # 2
# Error on phrase: i hate towel head, page # 1
# Error on phrase: i hate all towel head, page # 1
# Search Results Found for down with the towel head: page # 1
# Error on phrase: down with the towel head, page # 2
# Search Results Found for rag head people are: page # 1
# Error on phrase: rag head people are, page # 2
# Search Results Found for rag head are: page # 1
# Error on phrase: rag head are, page # 2
# Search Results Found for all rag head are: page # 1
# Error on phrase: all rag head are, page # 2
# Error on phrase: i hate rag head, page # 1
# Error on phrase: i hate all rag head, page # 1
# Search Results Found for down with the rag head: page # 1
# Error on phrase: down with the rag head, page # 2

# %%
racist_2 = pd.DataFrame({
    "race": race_list,
    "phrase": phrase_from_list,
    "time": time,
    "tweet": text,
    "# of hastags": num_hashtags,
    "# of mentions": num_user_mentions,
    "screen name": screen_name,
    "user id": user_id,
    "name": name,
    "account creation date": account_creation_time,
    "number of account tweets": user_tweet_count,
    "location": location,
    "# followers": num_followers,
    "# following": num_following,
    "# retweets of tweet": num_retweets,
    "# favorite of tweet": num_favorites,
    "in reply to": in_reply_to
})

# %%
len(racist_2)
# Out:
# 79

# %%
racist_2.to_csv('racist_2.csv')
