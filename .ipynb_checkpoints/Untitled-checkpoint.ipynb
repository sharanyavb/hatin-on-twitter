# %%
import pandas as pd
import requests as req
import random

# %%
us_postal_codes = pd.io.parsers.read_csv('us_postal_codes.csv', dtype={'Zip Code': 'str'})

# %%
us_postal_codes_df = pd.DataFrame(us_postal_codes)
us_postal_codes_df.rename(columns = {"State.1": "State Abbreviation", "State Abbreviation": "County"}, inplace=True)
us_postal_codes_df.head()
# Out:
#   Zip Code  Place Name          State State Abbreviation     County  Latitude  \
# 0    00501  Holtsville       New York                 NY    Suffolk   40.8154
# 1    00544  Holtsville       New York                 NY    Suffolk   40.8154
# 2    01001      Agawam  Massachusetts                 MA    Hampden   42.0702
# 3    01002     Amherst  Massachusetts                 MA  Hampshire   42.3671
# 4    01003     Amherst  Massachusetts                 MA  Hampshire   42.3919
#
#    Longitude
# 0   -73.0451
# 1   -73.0451
# 2   -72.6227
# 3   -72.4646
# 4   -72.5248

# %%
# Lists for DataFrame
zip_code = []
place_name = []
state = []
state_abb = []
county = []
lat = []
lng = []

# %%
# Range of random numbers to chose from and list of random numbers used so far
a = range(40933)
rand_num = []

while len(zip_code) < 200:
    
    # Get a random index number
    b = a[random.randint(0,len(a))]

    if b in rand_num:
        continue
    else:
        city = us_postal_codes_df.iloc[b,:]
    
        # Appending data
        zip_code.append(city['Zip Code'])
        place_name.append(city['Place Name'])
        state.append(city['State'])
        state_abb.append(city['State Abbreviation'])
        county.append(city['County'])
        lat.append(city['Latitude'])
        lng.append(city['Longitude'])

# %%
cities = {
    "Zip Code": zip_code,
    "City Name": place_name,
    "State": state,
    "State Abbreviation": state_abb,
    "County": county,
    "Latitude": lat,
    "Longitude": lng
}

# %%
cities_df = pd.DataFrame(cities)

# %%
cities_df
# Out:
#             City Name                            County  Latitude  Longitude  \
# 0          Eden Mills                          Lamoille   44.6931   -72.5134
# 1                Lebo                            Coffey   38.4161   -95.8222
# 2               Ronan                              Lake   47.5525  -114.1054
# 3             Roxbury                           Addison   44.0846   -72.7202
# 4      Cape Canaveral                           Brevard   28.3903   -80.6043
# 5              Lawley                              Bibb   32.8646   -86.9567
# 6            Spangler                           Cambria   40.6351   -78.7692
# 7             Houston                            Harris   29.8340   -95.4342
# 8        Cedar Rapids                              Linn   42.0794   -91.5992
# 9        Cartersville                            Bartow   34.1870   -84.8204
# 10          Elk Grove                        Sacramento   38.4232  -121.3599
# 11          Whitehall                       Trempealeau   44.3827   -91.3030
# 12       Lawrenceburg                          Lawrence   35.2507   -87.3526
# 13    Shawnee Mission                           Johnson   38.8999   -94.8320
# 14    Charlottesville            Charlottesville (city)   38.0339   -78.4924
# 15       North Greece                            Monroe   43.2578   -77.7351
# 16         Fort Wayne                             Allen   41.0938   -85.0707
# 17        Honey Grove                            Fannin   33.5985   -95.9109
# 18         Sacramento                        Sacramento   38.5383  -121.5549
# 19            Reading                            Nobles   43.7136   -95.7389
# 20        Mount Holly                      Westmoreland   38.1182   -76.6805
# 21   North Charleston                        Charleston   32.8929   -80.0458
# 22         Wood River                              Hall   40.8106   -98.6065
# 23         Ponca City                               Kay   36.7031   -97.0784
# 24             Saline                         Washtenaw   42.1698   -83.7849
# 25             Albert                             Caddo   35.2032   -98.3574
# 26              Miami                            Ottawa   36.8341   -94.8770
# 27        Albuquerque                        Bernalillo   35.1347  -106.6427
# 28             Wapato                            Yakima   46.4507  -120.4265
# 29          Stockland                          Iroquois   40.6145   -87.5928
# ..                ...                               ...       ...        ...
# 170            Elbert                            Elbert   39.0969  -104.5746
# 171          Davidson                           Tillman   34.2514   -99.0640
# 172            Denver                         Jefferson   39.7123  -105.0918
# 173       Dewittville                        Chautauqua   42.2394   -79.4193
# 174        Etna Green                         Kosciusko   41.2918   -86.0350
# 175        Sacramento                        Sacramento   38.5816  -121.4944
# 176           Valmora                              Mora   35.8164  -104.9231
# 177            Ludlow                           Windsor   43.3929   -72.7002
# 178     San Francisco  City and County of San Francisco   37.7631  -122.4586
# 179             Tyler                             Smith   32.4190   -95.2106
# 180        Lelia Lake                            Donley   34.8843  -100.7674
# 181          Nashotah                          Waukesha   43.1118   -88.4089
# 182             Kelly                          Caldwell   31.9648   -92.1825
# 183      Indianapolis                            Marion   39.6789   -86.1302
# 184           Bradley                           Raleigh   37.8654   -81.1940
# 185            Austin                            Travis   30.3093   -97.7242
# 186      Millersville                    Cape Girardeau   37.4401   -89.7950
# 187      Cedar Island                          Carteret   35.0082   -76.3160
# 188          La Jolla                         San Diego   32.8473  -117.2742
# 189         Frederica                              Kent   39.0342   -75.4545
# 190           Houston                            Harris   29.7633   -95.3633
# 191      New Florence                      Westmoreland   40.3823   -79.0968
# 192            Jersey                            Walton   33.7180   -83.8015
# 193              Burt                           Kossuth   43.2062   -94.2122
# 194        Brookhaven                           Suffolk   40.7843   -72.8921
# 195       Baton Rouge           East Baton Rouge Parish   30.4050   -91.1868
# 196              Deer                            Newton   35.8530   -93.3174
# 197     Golden Valley                            Mercer   47.2938  -102.0612
# 198           Elkhart                             Logan   40.0132   -89.4520
# 199  Key Colony Beach                            Monroe   24.7234   -81.0203
#
#               State State Abbreviation Zip Code
# 0           Vermont                 VT    05653
# 1            Kansas                 KS    66856
# 2           Montana                 MT    59864
# 3           Vermont                 VT    05669
# 4           Florida                 FL    32920
# 5           Alabama                 AL    36793
# 6      Pennsylvania                 PA    15775
# 7             Texas                 TX    77238
# 8              Iowa                 IA    52407
# 9           Georgia                 GA    30120
# 10       California                 CA    95624
# 11        Wisconsin                 WI    54773
# 12        Tennessee                 TN    38464
# 13           Kansas                 KS    66276
# 14         Virginia                 VA    22903
# 15         New York                 NY    14515
# 16          Indiana                 IN    46895
# 17            Texas                 TX    75446
# 18       California                 CA    95899
# 19        Minnesota                 MN    56165
# 20         Virginia                 VA    22524
# 21   South Carolina                 SC    29418
# 22         Nebraska                 NE    68883
# 23         Oklahoma                 OK    74601
# 24         Michigan                 MI    48176
# 25         Oklahoma                 OK    73001
# 26         Oklahoma                 OK    74355
# 27       New Mexico                 NM    87107
# 28       Washington                 WA    98951
# 29         Illinois                 IL    60967
# ..              ...                ...      ...
# 170        Colorado                 CO    80106
# 171        Oklahoma                 OK    73530
# 172        Colorado                 CO    80226
# 173        New York                 NY    14728
# 174         Indiana                 IN    46524
# 175      California                 CA    94204
# 176      New Mexico                 NM    87750
# 177         Vermont                 VT    05149
# 178      California                 CA    94143
# 179           Texas                 TX    75708
# 180           Texas                 TX    79240
# 181       Wisconsin                 WI    53058
# 182       Louisiana                 LA    71441
# 183         Indiana                 IN    46227
# 184   West Virginia                 WV    25818
# 185           Texas                 TX    78751
# 186        Missouri                 MO    63766
# 187  North Carolina                 NC    28520
# 188      California                 CA    92039
# 189        Delaware                 DE    19946
# 190           Texas                 TX    77212
# 191    Pennsylvania                 PA    15944
# 192         Georgia                 GA    30018
# 193            Iowa                 IA    50522
# 194        New York                 NY    11719
# 195       Louisiana                 LA    70803
# 196        Arkansas                 AR    72628
# 197    North Dakota                 ND    58541
# 198        Illinois                 IL    62634
# 199         Florida                 FL    33051
#
# [200 rows x 7 columns]

# %%
cities_df.to_csv("random_cities.csv", index=False)
