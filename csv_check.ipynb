# %%
import pandas as pd

# %%
df = pd.read_csv('black_racist_tweets.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 # favorite of tweet  # followers # following # of hastags  \
# 0         0.0                   4          320         233            0
# 1         1.0                   0          530         474            0
# 2         2.0                   0         1219         281            0
# 3         3.0                   0         1219         281            0
# 4         4.0                   0         2518        5001            1
#
#                                        # of mentions # retweets of tweet  \
# 0  [{'screen_name': 'BlackieWFangs', 'name': 'Bla...                   0
# 1                                                 []                   0
# 2  [{'screen_name': 'issa_blackie', 'name': 'Blac...                   0
# 3  [{'screen_name': 'issa_blackie', 'name': 'Blac...                   0
# 4  [{'screen_name': 'caitlin_blackie', 'name': 'C...                   0
#
#             account creation date   in reply to        location  \
# ...

# %%
df['term'].value_counts()
# Out:
# house nigger       435
# nigger             399
# mammy              330
# nigglet            289
# boon               283
# nigra              278
# jig                270
# jigaboo            269
# spook              268
# coon               254
# negress            228
# nappy head         214
# porch monkey       194
# spade              178
# negro              155
# swamper            148
# negroid            129
# darkie             127
# boogie              95
# hutch               79
# thick lips          78
# jigga               75
# blackie             68
# swamp donkey        63
# monkeyboy           37
# bonky               26
# knuckle-dragger     24
# jungle bunny        19
# yard ape            19
# field nigger        16
# bo-bo               15
# pube head           13
# liver lips          13
# niggerino            4
# buppie               4
# ghetto monkey        3
# cotton-picker        3
# strap hangers        2
# chain dragger        2
# zoo ape              2
# ...
