# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import math

# %%
normalized_counts = pd.read_csv("normalized_counts.csv", dtype={"Total Population":np.int32, "total_norm":np.float64,
                                                               "total_count":np.int32})
del normalized_counts["Unnamed: 0"]
normalized_counts.head()
# Out:
#         State  Total Population State Abbr  black  jews  muslim  norm_black  \
# 0     Alabama           4863300         AL    1.0   1.0     4.0    0.000021
# 1      Alaska            741894         AK    1.0   0.0     1.0    0.000135
# 2     Arizona           6931071         AZ    1.0   0.0     4.0    0.000014
# 3    Arkansas           2988248         AR    3.0   1.0     3.0    0.000100
# 4  California          39250017         CA   30.0  31.0    17.0    0.000076
#
#    norm_jewish  norm_muslim  total_count  total_norm
# 0     0.000021     0.000082            6    0.000123
# 1     0.000000     0.000135            2    0.000270
# 2     0.000000     0.000058            5    0.000072
# 3     0.000033     0.000100            7    0.000234
# 4     0.000079     0.000043           78    0.000199

# %%
norm_mean = normalized_counts['total_norm'].mean()
norm_mean
# Out:
# 0.00024554813413097976

# %%
total_pop = normalized_counts['Total Population'].sum()
total_pop
# Out:
# 315321496

# %%
normalized_counts["Normalized Population"] = ""
normalized_counts.head()
# Out:
#         State  Total Population State Abbr  black  jews  muslim  norm_black  \
# 0     Alabama           4863300         AL    1.0   1.0     4.0    0.000021
# 1      Alaska            741894         AK    1.0   0.0     1.0    0.000135
# 2     Arizona           6931071         AZ    1.0   0.0     4.0    0.000014
# 3    Arkansas           2988248         AR    3.0   1.0     3.0    0.000100
# 4  California          39250017         CA   30.0  31.0    17.0    0.000076
#
#    norm_jewish  norm_muslim  total_count  total_norm Normalized Population
# 0     0.000021     0.000082            6    0.000123
# 1     0.000000     0.000135            2    0.000270
# 2     0.000000     0.000058            5    0.000072
# 3     0.000033     0.000100            7    0.000234
# 4     0.000079     0.000043           78    0.000199

# %%
for index,row in normalized_counts.iterrows():
    norm_pop = row['Total Population'] / total_pop
    
    normalized_counts.set_value(index, 'Normalized Population', norm_pop)

# %%
normalized_counts.head()
# Out:
#         State  Total Population State Abbr  black  jews  muslim  norm_black  \
# 0     Alabama           4863300         AL    1.0   1.0     4.0    0.000021
# 1      Alaska            741894         AK    1.0   0.0     1.0    0.000135
# 2     Arizona           6931071         AZ    1.0   0.0     4.0    0.000014
# 3    Arkansas           2988248         AR    3.0   1.0     3.0    0.000100
# 4  California          39250017         CA   30.0  31.0    17.0    0.000076
#
#    norm_jewish  norm_muslim  total_count  total_norm Normalized Population
# 0     0.000021     0.000082            6    0.000123             0.0154233
# 1     0.000000     0.000135            2    0.000270            0.00235282
# 2     0.000000     0.000058            5    0.000072              0.021981
# 3     0.000033     0.000100            7    0.000234            0.00947683
# 4     0.000079     0.000043           78    0.000199              0.124476

# %%
norm_pop_mean = normalized_counts['Normalized Population'].mean()
sample_data = normalized_counts['total_count']
alabama = [1,1,1,1,1,1]
for x in range(4863294):
    alabama.append(0)

# %%
total_tweets = int(normalized_counts['total_count'].sum())
pop = []
for x in range(total_tweets):
    pop.append(1)
    
for x in range(total_pop - total_tweets):
    pop.append(0)

# %%
result = stats.ttest_1samp(a=alabama, popmean=np.mean(pop))

# %%
normalized_counts['P-Value'] = ""
normalized_counts.head()
# Out:
#         State  Total Population State Abbr  black  jews  muslim  norm_black  \
# 0     Alabama           4863300         AL    1.0   1.0     4.0    0.000021
# 1      Alaska            741894         AK    1.0   0.0     1.0    0.000135
# 2     Arizona           6931071         AZ    1.0   0.0     4.0    0.000014
# 3    Arkansas           2988248         AR    3.0   1.0     3.0    0.000100
# 4  California          39250017         CA   30.0  31.0    17.0    0.000076
#
#    norm_jewish  norm_muslim  total_count  total_norm Normalized Population  \
# 0     0.000021     0.000082            6    0.000123             0.0154233
# 1     0.000000     0.000135            2    0.000270            0.00235282
# 2     0.000000     0.000058            5    0.000072              0.021981
# 3     0.000033     0.000100            7    0.000234            0.00947683
# 4     0.000079     0.000043           78    0.000199              0.124476
#
#   P-Value
# 0
# 1
# 2
# 3
# 4

# %%
for index,row in normalized_counts.iterrows():
    data = []
    num_1 = row['total_count']
    for x in range(num_1):
        data.append(1)
        
    state_pop = row['Total Population']
    num_2 = state_pop - num_1
    for x in range(num_2):
        data.append(0)
        
    result = stats.ttest_1samp(a=data, popmean=np.mean(pop))
    
    normalized_counts.set_value(index, 'P-Value', result[1])

# %%
del normalized_counts['index']
normalized_counts
# Out:
#              State  Total Population State Abbr  black  jews  muslim  \
# 0          Alabama           4863300         AL    1.0   1.0     4.0
# 1           Alaska            741894         AK    1.0   0.0     1.0
# 2          Arizona           6931071         AZ    1.0   0.0     4.0
# 3         Arkansas           2988248         AR    3.0   1.0     3.0
# 4       California          39250017         CA   30.0  31.0    17.0
# 5         Colorado           5540545         CO    4.0   0.0     3.0
# 6      Connecticut           3576452         CT    2.0   2.0     1.0
# 7         Delaware            952065         DE    3.0   1.0     0.0
# 8          Florida          20612439         FL   19.0  13.0    14.0
# 9          Georgia          10310371         GA   10.0   5.0     4.0
# 10           Idaho           1683140         ID    0.0   1.0     0.0
# 11        Illinois          12801539         IL   11.0   2.0     6.0
# 12         Indiana           6633053         IN    1.0   3.0     3.0
# 13          Kansas           2907289         KS    1.0   2.0     1.0
# 14        Kentucky           4436974         KY    2.0   3.0     2.0
# 15       Louisiana           4681666         LA    8.0   2.0     3.0
# 16           Maine           1331479         ME    1.0   0.0     0.0
# 17        Maryland           6016447         MD    6.0   5.0     1.0
# 18   Massachusetts           6811779         MA    3.0   5.0     3.0
# 19        Michigan           9928300         MI   16.0   9.0     7.0
# 20       Minnesota           5519952         MN    3.0   5.0     2.0
# 21     Mississippi           2988726         MS    5.0   1.0     7.0
# 22        Missouri           6093000         MO    7.0   2.0     1.0
# 23        Nebraska           1907116         NE    0.0   0.0     2.0
# 24          Nevada           2940058         NV    4.0   1.0     2.0
# 25      New Jersey           8944469         NJ    7.0   5.0     2.0
# 26      New Mexico           2081015         NM    0.0   1.0     2.0
# 27        New York          19745289         NY   20.0  22.0    13.0
# 28  North Carolina          10146788         NC    8.0   3.0     5.0
# 29    North Dakota            757953         ND    0.0   1.0     0.0
# 30            Ohio          11614373         OH    4.0   4.0     4.0
# 31        Oklahoma           3923561         OK    4.0   2.0     3.0
# 32          Oregon           4093465         OR    1.0   3.0     2.0
# 1             0.00235282     0.699459
# 2               0.021981  0.000123543
# 3             0.00947683     0.665644
# 4               0.124476     0.903236
# 5              0.0175711     0.144691
# 6              0.0113422     0.368824
# 7             0.00301935     0.285962
# 8              0.0653696     0.408855
# 9               0.032698     0.781793
# 10            0.00533785    0.0215168
# 11             0.0405984     0.162385
# 12             0.0210358    0.0233387
# 13            0.00922008     0.395879
# 14             0.0140713     0.521493
# 15             0.0148473     0.288829
# 16            0.00422261     0.107492
# 17             0.0190804     0.952042
# 18             0.0216026     0.478521
# 19             0.0314863      0.02662
# 20             0.0175058     0.795745
# 21            0.00947835    0.0475976
# 22             0.0193231     0.539203
# 23            0.00604816     0.219152
# 24              0.009324     0.639904
# 25             0.0283662     0.345418
# 26            0.00659966     0.533465
# 27             0.0626195    0.0279459
# 28             0.0321792     0.331208
# 29            0.00240375     0.627311
# 30             0.0368334   0.00188978
# 31              0.012443     0.662306
# 32             0.0129819     0.408915
# 33             0.0405435     0.668158
# 34            0.00335031     0.591509
# 35             0.0157335     0.511038
# 36             0.0210934     0.539355
# 37             0.0883625     0.160839
# 38            0.00967653     0.322151
# 39            0.00198082     0.305226
# 40             0.0266769     0.333575
# 41             0.0231129     0.939543
# 42             0.0058071      0.26125
# 43             0.0183264  1.53326e-06
# 44            0.00185684     0.882717

# %%
normalized_counts.to_csv("norm_with_p_values.csv", index=False)

# %%
x_axis = np.arange(45)
y_axis = normalized_counts['P-Value']

plt.figure(figsize=(20,2))

plt.plot(x_axis, y_axis, "--o")

plt.title("P-Values for Hypothesis Testing")
plt.xlabel("State")
plt.ylabel("p-value")

x_labels = normalized_counts['State']
x_locations = [value for value in np.arange(45)]
plt.xticks(x_locations, x_labels, rotation=90)

plt.savefig("Images/p-value.png", bbox_inches='tight')

plt.show()

# %%
normalized_counts.loc[normalized_counts['P-Value'] < 0.05]
# Out:
#           State  Total Population State Abbr  black  jews  muslim  norm_black  \
# 2       Arizona           6931071         AZ    1.0   0.0     4.0    0.000014
# 10        Idaho           1683140         ID    0.0   1.0     0.0    0.000000
# 12      Indiana           6633053         IN    1.0   3.0     3.0    0.000015
# 19     Michigan           9928300         MI   16.0   9.0     7.0    0.000161
# 21  Mississippi           2988726         MS    5.0   1.0     7.0    0.000167
# 27     New York          19745289         NY   20.0  22.0    13.0    0.000101
# 30         Ohio          11614373         OH    4.0   4.0     4.0    0.000034
# 43    Wisconsin           5778709         WI    2.0   1.0     0.0    0.000035
#
#     norm_jewish  norm_muslim  total_count  total_norm Normalized Population  \
# 2      0.000000     0.000058            5    0.000072              0.021981
# 10     0.000059     0.000000            1    0.000059            0.00533785
# 12     0.000045     0.000045            7    0.000106             0.0210358
# 19     0.000091     0.000071           32    0.000322             0.0314863
# 21     0.000033     0.000234           13    0.000435            0.00947835
# 27     0.000111     0.000066           55    0.000279             0.0626195
# 30     0.000034     0.000034           12    0.000103             0.0368334
# 43     0.000017     0.000000            3    0.000052             0.0183264
#
#         P-Value
# 2   0.000123543
# 10    0.0215168
# 12    0.0233387
# 19      0.02662
# 21    0.0475976
# 27    0.0279459
# 30   0.00188978
# 43  1.53326e-06
