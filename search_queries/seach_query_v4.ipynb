# %%
import tweepy
import json
import keys
from hate_speech1 import race_dict
import pandas as pd

# get keys
consumer_key = "dhdP8LaOYfkxmxi9Fwde6XtNs"
consumer_secret = "52yu7buJCQdZ44f9niYauSg6aXHLqHUKjZVXM8HqPxYooKPWVB"
access_token = "1570660926-Ck2MtiaK9ys8AiyDUBsgL3RV3in8GigvkcUPRAp"
access_token_secret = "765YZYKpMvfK8PDXWUxCa2yxZKnf5auAiASwpLNxYCbGO"

#autheticate
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser(), wait_on_rate_limit = True, wait_on_rate_limit_notify = True)

# %%
#data lists
race_list = []
phrase_from_list = []
time = []
text = []
num_hashtags = []
hashtag_list = []
num_user_mentions = []
user_id = []
name = []
screen_name = []
account_creation_time = []
user_tweet_count = []
location = []
num_followers = []
num_following = []
num_retweets = []
num_favorites = []
in_reply_to = []

phrase_list = []

# %%
cities_df = pd.read_csv('cities_new_coord.csv')

# %%
cities_df.head()
# Out:
#     City Name        County  Latitude  Longitude     State State Abbreviation  \
# 0   Morganton        Fannin   34.8714   -84.2115   Georgia                 GA
# 1  Dove Creek       Dolores   37.7632  -108.9181  Colorado                 CO
# 2      Belvue  Pottawatomie   39.2273   -96.1866    Kansas                 KS
# 3  New Berlin      Sangamon   39.7681   -89.8550  Illinois                 IL
# 4      Denver        Denver   39.6667  -105.0854  Colorado                 CO
#
#    Zip Code    new_lat     new_lng
# 0     30560  34.878161  -84.246319
# 1     81324  37.766100 -108.905939
# 2     66407  39.216663  -96.178051
# 3     62670  39.725328  -89.910663
# 4     80227  39.739236 -104.990251

# %%
def search_phrase(race):
    for race in race_dict[race]:
        phrase0 = race + ' people are'
        phrase1 = race + ' are'
        phrase2 = 'all ' + race + ' are'
        phrase3 = 'i hate ' + race
        phrase4 = 'i hate all ' + race
        phrase5 = 'down with the ' + race
        phrase_list.append(phrase0)
        phrase_list.append(phrase1)
        phrase_list.append(phrase2)
        phrase_list.append(phrase3)
        phrase_list.append(phrase4)
        phrase_list.append(phrase5)

# def search_phrases(phrase_list):
#         for entry in phrase_list: 
#             print(entry)



def search_request(race_name, search_term):
    page_num = 1
    for x in range(50): #enough to exhaust the search
        if x == 0:
            end_id = None
        try: #-filter:retweets   #and (not tweet["retweeted"]) and ("RT" not in tweet["text"]) REMOVE RETWEET DUPLICATES
            response = api.search(search_term, lang = "en", count = 100, max_id = end_id, geocode="39.82,-98.57,1500mi")['statuses']
            for tweet in response:
                tweet_text = tweet['text']
                if ("RT" not in tweet_text) and (search_term in tweet_text): 
                    #print('Success 1')
                    race_list.append(race_name)
                    #print('race name appended')
                    phrase_from_list.append(search_term)
                    #print('search term appended')
                    time.append(tweet['created_at'])
                    #print('time appended')
                    text.append(tweet['text'])
                    #print('text appended')
                    num_hashtags_tweet = len(tweet['entities']['hashtags'])
                    num_hashtags.append(num_hashtags_tweet)
                    hashtags = []
                    if num_hashtags_tweet > 0:
                        for hastag_text in tweet['entities']['hashtags']:
                            hashtags.append(hastag_text['text'])
                    hashtag_list.append(hashtags)
                    num_user_mentions.append(len(tweet['entities']['user_mentions']))
                    user_id.append(tweet['user']['id'])
                    screen_name.append(tweet['user']['screen_name'])
                    name.append(tweet['user']['name'])
                    account_creation_time.append(tweet['user']['created_at'])
                    user_tweet_count.append(tweet['user']['statuses_count'])
                    location.append(tweet['user']['location']) 
                    num_followers.append(tweet['user']['followers_count'])
                    num_following.append(tweet['user']['friends_count'])
                    num_retweets.append(tweet['retweet_count'])
                    num_favorites.append(tweet["favorite_count"])  
                    in_reply_to.append(tweet["in_reply_to_user_id"]) 
                    #print('Success 2!')
            end_id = response[-1]['id'] - 1
            print("Search Results Found for %s: page # %s" % (search_term, page_num))
        except: 
            print('Error on phrase: %s, page # %s' % (search_term, page_num))
            break
        page_num += 1

# for term in black:
#     slur = term.lower()
#     search_request(slur)
#     print("Results for %s: %s" % (term, len(word)))
#-------------------------------------
##### for phrases 
#     for key in race_dict.keys():
#         #print(key)
#         search_phrase(key)
#         #print(phrase_list)
#         for phrase in phrase_list:
#             #print(key, phrase)
#             search_request(key, phrase)
#         phrase_list = []
#         #print(phrase_list)
# ------------------------------------

for key in race_dict.keys():
    for word in race_dict[key]:
        search_request(key, word)
    
#search_request('black', 'black are')
# print(location)
# print(race_list)
# for n in text:
#     print(n)
# print(location)
# print(text)


# user_location = []
# profile_location = []
# timezone = []


# def user_location():
#     for name in screen_name:
#         try: #-filter:retweets   #and (not tweet["retweeted"]) and ("RT" not in tweet["text"])
#             response = api.get_user(name)
#             for tweet in response:
#                 user_location.append(response["location"])
#                 profile_location.append(response["profile_location"])
# Out:
# Search Results Found for jigaboo: page # 1
# Search Results Found for jigaboo: page # 2
# Error on phrase: jigaboo, page # 3
# Search Results Found for coon: page # 1
# Search Results Found for coon: page # 2
# Search Results Found for coon: page # 3
# Search Results Found for coon: page # 4
# Search Results Found for coon: page # 5
# Search Results Found for coon: page # 6
# Search Results Found for coon: page # 7
# Search Results Found for coon: page # 8
# Search Results Found for coon: page # 9
# Search Results Found for coon: page # 10
# Search Results Found for coon: page # 11
# Search Results Found for coon: page # 12
# Rate limit reached. Sleeping for: 687
# Search Results Found for coon: page # 13
# Search Results Found for coon: page # 14
# Search Results Found for coon: page # 15
# Search Results Found for coon: page # 16
# Search Results Found for coon: page # 17
# Search Results Found for coon: page # 18
# Search Results Found for coon: page # 19
# Search Results Found for coon: page # 20
# Search Results Found for coon: page # 21
# Search Results Found for coon: page # 22
# Search Results Found for coon: page # 23
# Search Results Found for coon: page # 24
# Search Results Found for coon: page # 25
# Search Results Found for coon: page # 26
# Search Results Found for coon: page # 27
# Search Results Found for coon: page # 28
# Search Results Found for coon: page # 29
# Search Results Found for coon: page # 30
# Search Results Found for coon: page # 31
# Search Results Found for coon: page # 32
# Search Results Found for coon: page # 33
# Search Results Found for coon: page # 34
# Search Results Found for coon: page # 35
# Search Results Found for coon: page # 36
# Search Results Found for coon: page # 37
# Search Results Found for coon: page # 38
# Search Results Found for coon: page # 39
# Search Results Found for coon: page # 40
# Search Results Found for coon: page # 41
# Search Results Found for coon: page # 42
# Search Results Found for coon: page # 43
# Search Results Found for coon: page # 44
# Search Results Found for coon: page # 45
# Search Results Found for coon: page # 46
# Search Results Found for coon: page # 47
# Search Results Found for coon: page # 48
# Search Results Found for coon: page # 49
# Search Results Found for coon: page # 50
# Search Results Found for spook: page # 1
# Search Results Found for spook: page # 2
# Search Results Found for spook: page # 3
# Search Results Found for spook: page # 4
# Search Results Found for spook: page # 5
# Search Results Found for spook: page # 6
# Search Results Found for spook: page # 7
# Search Results Found for spook: page # 8
# Search Results Found for spook: page # 9
# Search Results Found for spook: page # 10
# Search Results Found for spook: page # 11
# Search Results Found for spook: page # 12
# Search Results Found for spook: page # 13
# Search Results Found for spook: page # 14
# Search Results Found for spook: page # 15
# Search Results Found for spook: page # 16
# Search Results Found for spook: page # 17
# Search Results Found for spook: page # 18
# Search Results Found for spook: page # 19
# Search Results Found for spook: page # 20
# Search Results Found for spook: page # 21
# Search Results Found for spook: page # 22
# Search Results Found for spook: page # 23
# Search Results Found for spook: page # 24
# Search Results Found for spook: page # 25
# Search Results Found for spook: page # 26
# Search Results Found for spook: page # 27
# Search Results Found for spook: page # 28
# Search Results Found for spook: page # 29
# Search Results Found for spook: page # 30
# Search Results Found for spook: page # 31
# Search Results Found for spook: page # 32
# Error on phrase: spook, page # 33
# Search Results Found for porch monkey: page # 1
# Search Results Found for porch monkey: page # 2
# Error on phrase: porch monkey, page # 3
# Search Results Found for spade: page # 1
# Search Results Found for spade: page # 2
# Search Results Found for spade: page # 3
# Search Results Found for spade: page # 4
# Search Results Found for spade: page # 5
# Search Results Found for spade: page # 6
# Search Results Found for spade: page # 7
# Search Results Found for spade: page # 8
# Search Results Found for spade: page # 9
# Search Results Found for spade: page # 10
# Search Results Found for spade: page # 11
# Search Results Found for spade: page # 12
# Search Results Found for spade: page # 13
# Search Results Found for spade: page # 14
# Search Results Found for spade: page # 15
# Search Results Found for spade: page # 16
# Search Results Found for spade: page # 17
# Search Results Found for spade: page # 18
# Search Results Found for spade: page # 19
# Search Results Found for spade: page # 20
# Search Results Found for spade: page # 21
# Search Results Found for spade: page # 22
# Search Results Found for spade: page # 23
# Search Results Found for spade: page # 24
# Search Results Found for spade: page # 25
# Search Results Found for spade: page # 26
# Search Results Found for spade: page # 27
# Search Results Found for spade: page # 28
# Search Results Found for spade: page # 29
# Search Results Found for spade: page # 30
# Search Results Found for spade: page # 31
# Search Results Found for spade: page # 32
# Search Results Found for spade: page # 33
# Search Results Found for spade: page # 34
# Search Results Found for spade: page # 35
# Search Results Found for spade: page # 36
# Search Results Found for spade: page # 37
# Search Results Found for spade: page # 38
# Search Results Found for spade: page # 39
# Search Results Found for spade: page # 40
# Search Results Found for spade: page # 41
# Search Results Found for spade: page # 42
# Search Results Found for spade: page # 43
# Search Results Found for spade: page # 44
# Search Results Found for spade: page # 45
# Search Results Found for spade: page # 46
# Search Results Found for spade: page # 47
# Search Results Found for spade: page # 48
# Search Results Found for spade: page # 49
# Search Results Found for spade: page # 50
# Search Results Found for jews: page # 1
# Search Results Found for jews: page # 2
# Search Results Found for jews: page # 3
# Search Results Found for jews: page # 4
# Search Results Found for jews: page # 5
# Search Results Found for jews: page # 6
# Search Results Found for jews: page # 7
# Search Results Found for jews: page # 8
# Search Results Found for jews: page # 9
# Search Results Found for jews: page # 10
# Search Results Found for jews: page # 11
# Search Results Found for jews: page # 12
# Search Results Found for jews: page # 13
# Search Results Found for jews: page # 14
# Search Results Found for jews: page # 15
# Search Results Found for jews: page # 16
# Search Results Found for jews: page # 17
# Search Results Found for jews: page # 18
# Search Results Found for jews: page # 19
# Search Results Found for jews: page # 20
# Search Results Found for jews: page # 21
# Search Results Found for jews: page # 22
# Search Results Found for jews: page # 23
# Search Results Found for jews: page # 24
# Search Results Found for jews: page # 25
# Search Results Found for jews: page # 26
# Search Results Found for jews: page # 27
# Search Results Found for jews: page # 28
# Search Results Found for jews: page # 29
# Search Results Found for jews: page # 30
# Search Results Found for jews: page # 31
# Search Results Found for jews: page # 32
# Search Results Found for jews: page # 33
# Search Results Found for jews: page # 34
# Search Results Found for jews: page # 35
# Search Results Found for jews: page # 36
# Search Results Found for jews: page # 37
# Search Results Found for jews: page # 38
# Search Results Found for jews: page # 39
# Search Results Found for jews: page # 40
# Search Results Found for jews: page # 41
# Search Results Found for jews: page # 42
# Search Results Found for jews: page # 43
# Search Results Found for jews: page # 44
# Search Results Found for jews: page # 45
# Search Results Found for jews: page # 46
# Search Results Found for jews: page # 47
# Search Results Found for jews: page # 48
# Search Results Found for jews: page # 49
# Search Results Found for jews: page # 50
# Search Results Found for christ killer: page # 1
# Error on phrase: christ killer, page # 2
# Search Results Found for hebrew: page # 1
# Search Results Found for hebrew: page # 2
# Search Results Found for hebrew: page # 3
# Search Results Found for hebrew: page # 4
# Rate limit reached. Sleeping for: 728
# Search Results Found for hebrew: page # 5
# Search Results Found for hebrew: page # 6
# Search Results Found for hebrew: page # 7
# Search Results Found for hebrew: page # 8
# Search Results Found for hebrew: page # 9
# Search Results Found for hebrew: page # 10
# Search Results Found for hebrew: page # 11
# Search Results Found for hebrew: page # 12
# Search Results Found for hebrew: page # 13
# Search Results Found for hebrew: page # 14
# Search Results Found for hebrew: page # 15
# Search Results Found for hebrew: page # 16
# Search Results Found for hebrew: page # 17
# Search Results Found for hebrew: page # 18
# Search Results Found for hebrew: page # 19
# Search Results Found for hebrew: page # 20
# Search Results Found for hebrew: page # 21
# Search Results Found for hebrew: page # 22
# Search Results Found for hebrew: page # 23
# Search Results Found for hebrew: page # 24
# Search Results Found for hebrew: page # 25
# Search Results Found for hebrew: page # 26
# Search Results Found for hebrew: page # 27
# Search Results Found for hebrew: page # 28
# Search Results Found for hebrew: page # 29
# Search Results Found for hebrew: page # 30
# Search Results Found for hebrew: page # 31
# Search Results Found for hebrew: page # 32
# Search Results Found for hebrew: page # 33
# Search Results Found for hebrew: page # 34
# Search Results Found for hebrew: page # 35
# Search Results Found for hebrew: page # 36
# Search Results Found for hebrew: page # 37
# Search Results Found for hebrew: page # 38
# Search Results Found for hebrew: page # 39
# Search Results Found for hebrew: page # 40
# Search Results Found for hebrew: page # 41
# Search Results Found for hebrew: page # 42
# Search Results Found for hebrew: page # 43
# Search Results Found for hebrew: page # 44
# Search Results Found for hebrew: page # 45
# Search Results Found for hebrew: page # 46
# Search Results Found for hebrew: page # 47
# Search Results Found for hebrew: page # 48
# Search Results Found for hebrew: page # 49
# Search Results Found for hebrew: page # 50
# Search Results Found for heeb: page # 1
# Error on phrase: heeb, page # 2
# Search Results Found for hebe: page # 1
# Search Results Found for hebe: page # 2
# Search Results Found for hebe: page # 3
# Error on phrase: hebe, page # 4
# Search Results Found for kike: page # 1
# Search Results Found for kike: page # 2
# Search Results Found for kike: page # 3
# Search Results Found for kike: page # 4
# Search Results Found for kike: page # 5
# Search Results Found for kike: page # 6
# Search Results Found for kike: page # 7
# Search Results Found for kike: page # 8
# Search Results Found for kike: page # 9
# Search Results Found for kike: page # 10
# Search Results Found for kike: page # 11
# Search Results Found for kike: page # 12
# Search Results Found for kike: page # 13
# Search Results Found for kike: page # 14
# Error on phrase: kike, page # 15
# Error on phrase: jew-bag, page # 1
# Search Results Found for jew bag: page # 1
# Error on phrase: jew bag, page # 2
# Search Results Found for yid: page # 1
# Search Results Found for yid: page # 2
# Search Results Found for yid: page # 3
# Search Results Found for yid: page # 4
# Error on phrase: yid, page # 5
# Search Results Found for muslim: page # 1
# Search Results Found for muslim: page # 2
# Search Results Found for muslim: page # 3
# Search Results Found for muslim: page # 4
# Search Results Found for muslim: page # 5
# Search Results Found for muslim: page # 6
# Search Results Found for muslim: page # 7
# Search Results Found for muslim: page # 8
# Search Results Found for muslim: page # 9
# Search Results Found for muslim: page # 10
# Search Results Found for muslim: page # 11
# Search Results Found for muslim: page # 12
# Search Results Found for muslim: page # 13
# Search Results Found for muslim: page # 14
# Search Results Found for muslim: page # 15
# Search Results Found for muslim: page # 16
# Search Results Found for muslim: page # 17
# Search Results Found for muslim: page # 18
# Search Results Found for muslim: page # 19
# Search Results Found for muslim: page # 20
# Search Results Found for muslim: page # 21
# Search Results Found for muslim: page # 22
# Search Results Found for muslim: page # 23
# Search Results Found for muslim: page # 24
# Search Results Found for muslim: page # 25
# Search Results Found for muslim: page # 26
# Search Results Found for muslim: page # 27
# Search Results Found for muslim: page # 28
# Search Results Found for muslim: page # 29
# Search Results Found for muslim: page # 30
# Search Results Found for muslim: page # 31
# Search Results Found for muslim: page # 32
# Search Results Found for muslim: page # 33
# Search Results Found for muslim: page # 34
# Search Results Found for muslim: page # 35
# Search Results Found for muslim: page # 36
# Search Results Found for muslim: page # 37
# Search Results Found for muslim: page # 38
# Search Results Found for muslim: page # 39
# Search Results Found for muslim: page # 40
# Search Results Found for muslim: page # 41
# Search Results Found for muslim: page # 42
# Search Results Found for muslim: page # 43
# Search Results Found for muslim: page # 44
# Search Results Found for muslim: page # 45
# Search Results Found for muslim: page # 46
# Search Results Found for muslim: page # 47
# Search Results Found for muslim: page # 48
# Search Results Found for muslim: page # 49
# Search Results Found for muslim: page # 50
# Search Results Found for sand-nigger: page # 1
# Error on phrase: sand-nigger, page # 2
# Search Results Found for towel-head: page # 1
# Search Results Found for towel-head: page # 2
# Search Results Found for towel-head: page # 3
# Search Results Found for towel-head: page # 4
# Error on phrase: towel-head, page # 5
# Error on phrase: rag-head, page # 1
# Search Results Found for sand nigger: page # 1
# Error on phrase: sand nigger, page # 2
# Search Results Found for towel head: page # 1
# Search Results Found for towel head: page # 2
# Search Results Found for towel head: page # 3
# Search Results Found for towel head: page # 4
# Error on phrase: towel head, page # 5
# Search Results Found for rag head: page # 1
# Search Results Found for rag head: page # 2
# Search Results Found for rag head: page # 3
# Error on phrase: rag head, page # 4
# Search Results Found for sandnigger: page # 1
# Error on phrase: sandnigger, page # 2
# Search Results Found for towelhead: page # 1
# Error on phrase: towelhead, page # 2
# Search Results Found for raghead: page # 1
# Search Results Found for raghead: page # 2
# Error on phrase: raghead, page # 3

# %%
racist_3 = pd.DataFrame({
    "race": race_list,
    "phrase": phrase_from_list,
    "time": time,
    "tweet": text,
    "# of hastags": num_hashtags,
    "# of mentions": num_user_mentions,
    "screen name": screen_name,
    "user id": user_id,
    "name": name,
    "account creation date": account_creation_time,
    "number of account tweets": user_tweet_count,
    "location": location,
    "# followers": num_followers,
    "# following": num_following,
    "# retweets of tweet": num_retweets,
    "# favorite of tweet": num_favorites,
    "in reply to": in_reply_to
})

# %%
racist_3 = racist_3.drop_duplicates()

# %%
len(racist_3.dropna(subset=['tweet']))
# Out:
# 4474

# %%
racist_3.to_csv('racist_3.csv')

# %%
len(racist_3)
# Out:
# 4474

# %%
classifier = pd.read_csv('class_output2.csv', header = None)

# %%
classifier.head()
# Out:
#              0
# 0      Neither
# 1      Neither
# 2      Neither
# 3  Hate speech
# 4      Neither

# %%
len(classifier)
# Out:
# 4474

# %%
racist_3['Classification']=classifier[0]

# %%
racist_3_filtered = racist_3[racist_3['Classification'] == 'Hate speech']

# %%
len(racist_3_filtered)
# Out:
# 766

# %%
racist_3_filtered.to_csv('racist_filtered.csv', index = False)
