# %%
import pandas as pd
import csv

# %%
filtered_results = pd.read_csv("filtered_results.csv")

# %%
filtered_df = pd.DataFrame(filtered_results)
filtered_df.head()
# Out:
#    Unnamed: 0  # favorite of tweet  # followers  # following  # of hastags  \
# 0           0                  0.0       1035.0        695.0           0.0
# 1           2                  0.0       2700.0        933.0           0.0
# 2           4                  0.0         34.0         80.0           0.0
# 3           6                  1.0       3007.0       5000.0           0.0
# 4          11                  0.0         32.0         19.0           0.0
#
#    # of mentions  # retweets of tweet           account creation date  \
# 0            0.0                  1.0  Mon May 10 20:46:10 +0000 2010
# 1            2.0                  0.0  Mon Oct 24 06:42:43 +0000 2011
# 2            2.0                  0.0  Mon Jun 06 20:29:37 +0000 2016
# 3            3.0                  0.0  Sun May 21 01:57:26 +0000 2017
# 4            0.0                  0.0  Wed Apr 16 18:29:54 +0000 2014
#
#     in reply to         location               name  number of account tweets  \
# ...

# %%
filtered_df['Racist (Y/N)'] = ""
filtered_df['Valid City Data (Y/N)'] = ""
filtered_df['State Abbreviation'] = ""
filtered_df
# Out:
#       Unnamed: 0  # favorite of tweet  # followers  # following  # of hastags  \
# 0              0                  0.0       1035.0        695.0           0.0
# 1              2                  0.0       2700.0        933.0           0.0
# 2              4                  0.0         34.0         80.0           0.0
# 3              6                  1.0       3007.0       5000.0           0.0
# 4             11                  0.0         32.0         19.0           0.0
# 5             13                  0.0       3362.0       1975.0           0.0
# 6             17                  0.0         50.0        148.0           0.0
# 7             29                  0.0         23.0         23.0           0.0
# 8             31                  0.0        138.0        134.0           0.0
# 9             32                  1.0        111.0        285.0           0.0
# 10            36                  0.0       3731.0       3436.0           3.0
# ...

# %%
sharanya = filtered_df.iloc[0:999]
ronessa = filtered_df.iloc[1000:1999]
mariah = filtered_df.iloc[2000:]

# %%
sharanya.to_csv("sharanya.csv", index=False)
ronessa.to_csv("ronessa.csv", index=False)
mariah.to_csv("mariah.csv", index=False)
