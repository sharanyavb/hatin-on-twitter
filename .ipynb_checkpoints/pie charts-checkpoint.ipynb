# %%
import pandas as pd

# %%
everything = pd.read_csv('hand_filtered/filtered_tweets.csv')

# %%
everything.head()
# Out:
#    # favorite of tweet  # followers  # following  # of hastags  # of mentions  \
# 0                    0         1035          695             0              0
# 1                    0           34           80             0              2
# 2                    1         3007         5000             0              3
# 3                    1            3            0             1              0
# 4                    0         2321         1198             0              0
#
#             account creation date   in reply to                 location  \
# 0  Mon May 10 20:46:10 +0000 2010           NaN          Los Angeles, CA
# 1  Mon Jun 06 20:29:37 +0000 2016  7.990000e+17           Tennessee, USA
# 2  Sun May 21 01:57:26 +0000 2017  7.810000e+17               Dallas, TX
# 3  Mon Aug 07 00:08:24 +0000 2017           NaN          Simi Valley, CA
# 4  Thu Aug 12 03:04:35 +0000 2010           NaN  East Flatbush, Brooklyn
#
# ...

# %%
everything[everything['State Abbreviation'] == 'AK']
# Out:
#      # favorite of tweet  # followers  # following  # of hastags  \
# 775                    1         2146         2184             0
# 951                    0          290          479             0
#
#      # of mentions           account creation date  in reply to location  \
# 775              2  Fri Sep 16 21:09:14 +0000 2016   52141764.0   alaska
# 951              0  Sun Jul 10 08:16:48 +0000 2011          NaN   Alaska
#
#                name  number of account tweets          ...             race  \
# 775  Deplorable me!                     35498          ...           muslim
# 951           Dedra                      9641          ...            black
#
#      screen name                            time  \
# 775  sneezerweez  Mon Sep 18 02:51:28 +0000 2017
# 951     Dedraiue  Thu Sep 21 13:54:43 +0000 2017
#
#                                                  tweet       user id  \
# 775  @winegirl73 @GartrellLinda I see your black ey...  7.770000e+17
# ...
